# %% [markdown]
# # Sommaire :
#
#
# ### <a href="#C1"> **Partie 1 : Contexte et Objectifs**</a>
#
#  - Contexte
#  - Objectifs
#
# <b><hr></b>
#
# ### <a href="#C2"> **Partie 2 : Mise en place de l'espace de travail**</a>
#  - <a href="#C21"> 2.1 Import des packages</a>
#  - <a href="#C22"> 2.2 Repertoire de travail</a>
#  - <a href="#C23"> 2.3 Import des datas frames</a>
#  - <a href="#C24"> 2.4 Definir la variable cible</a>
#
# <b><hr></b>
#
# ### <a href="#C3"> **Partie 3 : Data preparation**</a>
#  - <a href="#C31"> 3.1 Gestion des outliers</a>
#   - <a href="#C311"> 3.1.1 Boxplots</a>
#  - <a href="#C32"> 3.2 Graphiques</a>
#  - <a href="#C33"> 3.3 Transformation des variables</a>
#  - <a href="#C34"> 3.4 Create X & y</a>
#  - <a href="#C35"> 3.5 Train Test Split</a>
#  - <a href="#C36"> 3.6 Label Encoder </a>
#  - <a href="#C37"> 3.7 Feature Scaling </a>
#
# <b><hr></b>
#
# ### <a href="#C4"> **Partie 4 : Modélisation**</a>
#  - <a href="#C41"> 4.1 Dummy Estimator </a>
#  - <a href="#C42"> 4.2 Model type </a>
#  - <a href="#C43"> 4.3 Feature Selection </a>
#  - <a href="#C44"> 4.4 Model Selection </a>
#  - <a href="#C45"> 4.5 Fit best Model and get test score </a>
#  - <a href="#C46"> 4.6 Save Model </a>
#
# <b><hr></b>
#
# ### <a href="#C5"> **Partie 5 : Benchmark**</a>

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# </br>

# %% [markdown]
# # <a name="C1">**Partie 1 : Contexte et Objectifs**</a>

# %% [markdown]
# ![3EB5ED92-FE61-4EA3-A57D-1D29F74A5107](attachment:3EB5ED92-FE61-4EA3-A57D-1D29F74A5107)

# %% [markdown]
# Contexte

# %% [raw]
# Vous travaillez pour la ville de Seattle.
# Pour atteindre son objectif de ville neutre en émissions de carbone en 2050, votre équipe s’intéresse de près à la consommation et aux émissions des bâtiments non destinés à l’habitation.
#
# Des relevés minutieux ont été effectués par les agents de la ville en 2016. Voici les données et leur source. Cependant, ces relevés sont coûteux à obtenir, et à partir de ceux déjà réalisés, vous voulez tenter de prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments non destinés à l’habitation pour lesquels elles n’ont pas encore été mesurées.

# %% [markdown]
# Objectifs

# %% [raw]
# Anticipez les besoins en consommation de bâtiments:
#     -  Tenter de prédire les émissions de CO2 et la consommation totale d’énergie de bâtiments non destinés à l’habitation.
#     -  Cherchez à évaluer l’intérêt de l’"ENERGY STAR Score" pour la prédiction d’émissions, qui est fastidieux à calculer avec        l’approche utilisée actuellement par votre équipe.

# %% [markdown]
# <hr>

# %% [markdown]
# </br>

# %% [markdown]
# # <a name="C2"><font color='blue'>**Partie 2 : Mise en place de l'espace de travail**</font></a>

# %% [markdown]
# ### <a name="C21"><font color='blue'>2.1 Imports packages</font></a>

# %% [markdown]
# ###### <b><font color='blue'>2.1.0 Requirements</font></b>
# - <b>Built-in</b>       : os, warnings
# - <b>Data</b>           : pandas, numpy
# - <b>Visualisations</b> : matplotlib, seaborn
# - <b>Preprocessing</b>  : sklearn, scipy

# %% [markdown]
# ###### <b><font color='blue'>2.1.1 Imports</font></b>

# %%
# Built-in
import os,warnings

# Data
import numpy as np
import pandas as pd

#Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline

#Preprocessing
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler,MinMaxScaler,Normalizer

# feature selection
from sklearn.feature_selection import VarianceThreshold
from scipy.stats import entropy

# metrics
import sklearn as sk
from sklearn.metrics import auc,roc_curve,confusion_matrix

# Imputer
from sklearn.impute import KNNImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Modele Selection
from sklearn.model_selection import KFold, train_test_split, cross_val_score, GridSearchCV

# Model
from sklearn import dummy
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.svm import LinearSVR,SVR
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,BaggingRegressor,AdaBoostRegressor
from sklearn.ensemble import HistGradientBoostingRegressor,VotingRegressor,HistGradientBoostingRegressor
from lightgbm import LGBMRegressor
import xgboost as xgb
from sklearn import kernel_ridge
# Out:
# C:\Users\eleor\anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ###### <b><font color='blue'>2.1.2 Options</font></b>

# %%
#warnings.filterwarnings(action='ignore')
warnings.filterwarnings(action='once')

# %%
# option de cellule des pandas dataset
pd.set_option("display.max_rows", 200) #parametre le nombre de ligne affichable dans dataframe pandas
pd.set_option("expand_frame_repr", True) #permet de deplier les colonnes cachées
pd.set_option("display.max_columns",200 ) #permet d'afficher jusqu'à 200 colonnes dans une cellule

# %%
pd.set_option('max_colwidth', None)

# %% [raw]
# ### tqdm
# from tqdm import tqdm
# for i in tqdm(range(int(9e6))):
#     pass

# %% [markdown]
# ### <a name="C22"><font color='blue'>2.2 Working directory</font></a>

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'ELEORE_Kevin_1_notebook_exploratoire_112022.ipynb',
#  'ELEORE_Kevin_2_notebook_prediction_112022.ipynb',
#  'ELEORE_Kevin_3_notebook_prediction_112022.ipynb',
#  'ELEORE_Kevin_4_presentation_112022.pptx',
#  'ELEORE_Kevin_Anticipez les besoins en consommation de bâtiments.zip',
#  '~$ELEORE_Kevin_4_presentation_112022.pptx']

# %%
os.listdir('data/cleaned')
# Out:
# ['df_cleaned.csv', 'df_cleaned_AllUse.csv', 'df_cleaned_imputer_encod.csv']

# %%
path = 'data/cleaned/'
# A completer
filename = "df_cleaned.csv"

# %% [markdown]
# ### <a name="C23"><font color='blue'>2.3 Import DataFrames</font></a>

# %%
# df_encod = pd.read_csv(path+'df_cleaned.csv',sep=';',index_col='OSEBuildingID')

df = pd.read_csv(path+filename,sep=';',index_col='OSEBuildingID')
#df['ZipCode'] = df.ZipCode.apply(int).apply(str)
df.head()
# Out:
#                  BuildingType PrimaryPropertyType ZipCode  \
# OSEBuildingID
# 1              NonResidential               Hotel   98101
# 2              NonResidential               Hotel   98101
# 5              NonResidential               Hotel   98101
# 8              NonResidential               Hotel   98121
# 9              NonResidential               Other   98101
#
#                CouncilDistrictCode Neighborhood LargestPropertyUseType  \
# OSEBuildingID
# 1                                7     downtown                  hotel
# 2                                7     downtown                  hotel
# 5                                7     downtown                  hotel
# 8                                7     downtown                  hotel
# 9                                7     downtown               grouping
#
#               SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# OSEBuildingID
# 1                                     void                        void
# 2                                  parking                  restaurant
# 5                                     void                        void
# 8                                  parking               swimming pool
# 9                                     void                        void
#
#               FourthLargestPropertyUseType FifthLargestPropertyUseType  \
# OSEBuildingID
# 1                                     void                        void
# 2                                     void                        void
# 5                                     void                        void
# 8                                     void                        void
# 9                                     void                        void
#
#               SixthLargestPropertyUseType  Latitude  Longitude  \
# OSEBuildingID
# 1                                    void  47.61220 -122.33799
# 2                                    void  47.61317 -122.33393
# 5                                    void  47.61412 -122.33664
# 8                                    void  47.61375 -122.34047
# 9                                    void  47.61623 -122.33657
#
#                NumberofBuildings  NumberofFloors  PropertyGFATotal  \
# OSEBuildingID
# 1                            1.0            12.0           88434.0
# 2                            1.0            11.0          103566.0
# 5                            1.0            10.0           61320.0
# 8                            1.0            18.0          175580.0
# 9                            1.0             2.0           97288.0
#
#                PropertyGFAParking  PropertyGFABuilding(s)  \
# OSEBuildingID
# 1                             0.0                 88434.0
# 2                         15064.0                 88502.0
# 5                             0.0                 61320.0
# 8                         62000.0                113580.0
# 9                         37198.0                 60090.0
#
#                LargestPropertyUseTypeGFA  SecondLargestPropertyUseTypeGFA  \
# OSEBuildingID
# 1                                88434.0                              0.0
# 2                                83880.0                          15064.0
# 5                                61320.0                              0.0
# 8                               123445.0                          68009.0
# 9                                88830.0                              0.0
#
#                ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  \
# OSEBuildingID
# 1                                         0.0        60.000000
# 2                                      4622.0        61.000000
# 5                                         0.0        56.000000
# 8                                         0.0        75.000000
# 9                                         0.0        46.951391
#
#                SiteEnergyUseWN(kBtu)  TotalGHGEmissions  NumberofRooms  \
# OSEBuildingID
# 1                          7456910.0             249.98           12.0
# 2                          8664479.0             295.86           11.0
# 5                          6946800.5             286.43           10.0
# 8                         14656503.0             505.01           18.0
# 9                         12581712.0             301.81            2.0
#
#                NbTotalUseType   Age  dist_mean  dist_mean_CDC  \
# OSEBuildingID
# 1                         1.0  89.0   1.337395       1.273185
# 2                         3.0  20.0   1.209663       1.406095
# 5                         1.0  90.0   1.110927       1.183644
# 8                         3.0  36.0   1.219978       1.024299
# 9                         1.0  17.0   0.877805       1.044282
#
#                dist_mean_Neigh  Rate_GFABuilding   GFAperFloor
# OSEBuildingID
# 1                     0.402721          1.000000   7369.500000
# 2                     0.573195          0.854547   9415.090909
# 5                     0.617268          1.000000   6132.000000
# 8                     0.615997          0.646885   9754.444444
# 9                     0.851444          0.617651  48644.000000

# %%
df.drop(columns=['FourthLargestPropertyUseType'  ,'FifthLargestPropertyUseType','SixthLargestPropertyUseType'],
       inplace=True)

# %%
df.columns
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'ZipCode', 'CouncilDistrictCode',
#        'Neighborhood', 'LargestPropertyUseType',
#        'SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType',
#        'Latitude', 'Longitude', 'NumberofBuildings', 'NumberofFloors',
#        'PropertyGFATotal', 'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseTypeGFA', 'ENERGYSTARScore',
#        'SiteEnergyUseWN(kBtu)', 'TotalGHGEmissions', 'NumberofRooms',
#        'NbTotalUseType', 'Age', 'dist_mean', 'dist_mean_CDC',
#        'dist_mean_Neigh', 'Rate_GFABuilding', 'GFAperFloor'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3101 entries, 1 to 50226
# Data columns (total 29 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   BuildingType                     3101 non-null   object
#  1   PrimaryPropertyType              3101 non-null   object
#  2   ZipCode                          3101 non-null   object
#  3   CouncilDistrictCode              3101 non-null   int64
#  4   Neighborhood                     3101 non-null   object
#  5   LargestPropertyUseType           3101 non-null   object
#  6   SecondLargestPropertyUseType     3101 non-null   object
#  7   ThirdLargestPropertyUseType      3101 non-null   object
#  8   Latitude                         3101 non-null   float64
#  9   Longitude                        3101 non-null   float64
#  10  NumberofBuildings                3101 non-null   float64
#  11  NumberofFloors                   3101 non-null   float64
#  12  PropertyGFATotal                 3101 non-null   float64
#  13  PropertyGFAParking               3101 non-null   float64
#  14  PropertyGFABuilding(s)           3101 non-null   float64
#  15  LargestPropertyUseTypeGFA        3101 non-null   float64
#  16  SecondLargestPropertyUseTypeGFA  3101 non-null   float64
#  17  ThirdLargestPropertyUseTypeGFA   3101 non-null   float64
#  18  ENERGYSTARScore                  3101 non-null   float64
#  19  SiteEnergyUseWN(kBtu)            3101 non-null   float64
#  20  TotalGHGEmissions                3101 non-null   float64
#  21  NumberofRooms                    3101 non-null   float64
#  22  NbTotalUseType                   3101 non-null   float64
#  23  Age                              3101 non-null   float64
#  24  dist_mean                        3101 non-null   float64
#  25  dist_mean_CDC                    3101 non-null   float64
#  26  dist_mean_Neigh                  3101 non-null   float64
#  27  Rate_GFABuilding                 3101 non-null   float64
#  28  GFAperFloor                      3101 non-null   float64
# dtypes: float64(21), int64(1), object(7)
# memory usage: 726.8+ KB

# %% [markdown]
# ### <a name="C24"><font color='blue'>2.4 Define Target Data</font></a>

# %%
Target_data = 'TotalGHGEmissions'
df.drop(columns=['SiteEnergyUseWN(kBtu)'],inplace=True)

# %% [markdown]
# #### Suppression des lignes dont SiteEnergyUseWN(kBtu) sont NAs

# %%
df = df[df[Target_data].notna()]
df.shape
# Out:
# (3101, 28)

# %% [markdown]
# <hr>

# %% [markdown]
# </br>

# %% [markdown]
# # <a name="C3"><font color='teal'>**Partie 3 : Data preparation**</font></a>

# %% [markdown]
# ### <a name="C31"><font color='teal'>3.1 Gestion des outliers</font></a>

# %% [markdown]
# #### <a name="C311"><font color='teal'>3.1.1 Boxplots</font></a>

# %%
fig = plt.figure(figsize=(12, 5))
sns.boxplot(data = df.drop(columns=Target_data).select_dtypes(include=[np.number]) ,showfliers = True)
plt.xticks(rotation=45,size = 6);

# %% [markdown]
# <div class="alert alert-info">Les données comprennent encore beaucoups de valeurs extrèmes.<br>
# J'utiliserai quantileTransforme pour traiter les outliers</div>

# %%
df.columns
# Out:
# Index(['BuildingType', 'PrimaryPropertyType', 'ZipCode', 'CouncilDistrictCode',
#        'Neighborhood', 'LargestPropertyUseType',
#        'SecondLargestPropertyUseType', 'ThirdLargestPropertyUseType',
#        'Latitude', 'Longitude', 'NumberofBuildings', 'NumberofFloors',
#        'PropertyGFATotal', 'PropertyGFAParking', 'PropertyGFABuilding(s)',
#        'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseTypeGFA', 'ENERGYSTARScore',
#        'TotalGHGEmissions', 'NumberofRooms', 'NbTotalUseType', 'Age',
#        'dist_mean', 'dist_mean_CDC', 'dist_mean_Neigh', 'Rate_GFABuilding',
#        'GFAperFloor'],
#       dtype='object')

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

X_test = df.copy()

for col in ['PropertyGFATotal',
       'PropertyGFAParking', 'PropertyGFABuilding(s)',
       'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
       'ThirdLargestPropertyUseTypeGFA','GFAperFloor','Longitude']:
    #tandis que Yeo-Johnson prend en charge les données positives ou négatives.
    yj = PowerTransformer(method="yeo-johnson")
    qt = QuantileTransformer(output_distribution="normal")
    
    # perform power transforms and quantile transform
    X_test[col] = yj.fit_transform( X_test[col].values.reshape(-1,1) )
    #X_test[col] = qt.fit_transform( X_test[col].values.reshape(-1,1) )

# %%
fig = plt.figure(figsize=(12, 5))
sns.boxplot(data = X_test.drop(columns=Target_data).select_dtypes(include=[np.number]) ,showfliers = True)
plt.xticks(rotation=45,size = 6);

# %%
X_test[col]
# Out:
# OSEBuildingID
# 1       -1.385003e-14
# 2        5.800915e-15
# 5       -7.299716e-15
# 8       -2.586820e-14
# 9       -6.966649e-15
#              ...
# 50221   -1.901257e-13
# 50223    5.959122e-14
# 50224   -1.099676e-13
# 50225    5.243028e-14
# 50226    1.928457e-13
# Name: Longitude, Length: 3101, dtype: float64

# %% [markdown]
# ### <a name="C32"><font color='teal'> 3.2 Graphiques</font></a>

# %% [markdown]
# #### <font color='teal'> 3.2.1 Histogramme</font>

# %%
fig = plt.figure(figsize=(26, 12))
X_g = df.select_dtypes(include=np.number)
for feat_idx in range(X_g.shape[1]):
    ax = fig.add_subplot(7,3, (feat_idx+1))
    h = ax.hist(X_g.iloc[:, feat_idx], bins=50, color='steelblue', density=True, edgecolor='none')
    ax.set_title(X_g.columns[feat_idx], fontsize=14)
    
del X_g

# %%
fig = plt.figure(figsize=(26, 12))
X_g = X_test.select_dtypes(include=np.number)
for feat_idx in range(X_g.shape[1]):
    ax = fig.add_subplot(7,3, (feat_idx+1))
    h = ax.hist(X_g.iloc[:, feat_idx], bins=50, color='steelblue', density=True, edgecolor='none')
    ax.set_title(X_g.columns[feat_idx], fontsize=14)
    
del X_g

# %% [markdown]
# #### <font color='teal'> 3.2.2 Pairplot</font>

# %% [raw]
# df.select_dtypes(include=np.number).columns

# %%
fig = plt.figure(figsize=(26, 20))
X_g = df.select_dtypes(include=np.number)

#X_g['pourc_PropertyGFAParking'] = X_g['PropertyGFAParking']/X_g['PropertyGFATotal']
#X_g['pourc_PropertyGFABuilding'] = X_g['PropertyGFABuilding(s)']/X_g['PropertyGFATotal']

for feat_idx in range(X_g.shape[1]):
    ax = fig.add_subplot(7,3, (feat_idx+1))
    h = ax.scatter(X_g.iloc[:, feat_idx],X_g[Target_data] )
    ax.set_title(X_g.columns[feat_idx], fontsize=14)
    
del X_g

# %%
fig = plt.figure(figsize=(26, 20))
X_g = X_test.select_dtypes(include=np.number)

#X_g['pourc_PropertyGFAParking'] = X_g['PropertyGFAParking']/X_g['PropertyGFATotal']
#X_g['pourc_PropertyGFABuilding'] = X_g['PropertyGFABuilding(s)']/X_g['PropertyGFATotal']

for feat_idx in range(X_g.shape[1]):
    ax = fig.add_subplot(7,3, (feat_idx+1))
    h = ax.scatter(X_g.iloc[:, feat_idx],X_g[Target_data] )
    ax.set_title(X_g.columns[feat_idx], fontsize=14)
    
del X_g

# %%
np.corrcoef(np.log1p(X_test[Target_data]), X_test.LargestPropertyUseTypeGFA)
# Out:
# array([[1.        , 0.57338843],
#        [0.57338843, 1.        ]])

# %%
np.corrcoef(np.log1p(df[Target_data]), df.LargestPropertyUseTypeGFA)
# Out:
# array([[1.        , 0.50086277],
#        [0.50086277, 1.        ]])

# %%
X_num_to_test = df.select_dtypes(include=np.number).copy()
X_num_to_test['Age_bin'] = pd.cut(X_num_to_test.Age,bins=[0,5,10,15,20,30,40,50,60,70,80,90,130],include_lowest=True)
sns.boxplot(data=X_num_to_test,x = Target_data, y = 'Age_bin',showfliers=False);
del X_num_to_test

# %%
X_num_to_test = df.select_dtypes(include=np.number).copy()
X_num_to_test['PropertyBuilding_pourc'] = X_num_to_test['PropertyGFABuilding(s)']/X_num_to_test['PropertyGFATotal']
X_num_to_test['PropertyParking_pourc_bins'] = pd.cut(X_num_to_test.PropertyBuilding_pourc,bins=10,include_lowest=True)
sns.boxplot(data=X_num_to_test,x = Target_data, y = 'PropertyParking_pourc_bins',showfliers=False);
del X_num_to_test

# %% [raw]
# df['Age_bin'] = pd.cut(df.Age,bins=[0,5,10,15,20,50,80,130],include_lowest=True)
# df['PropertyGFAParking_bins'] = pd.cut(df.PropertyGFAParking,bins=[0,50000,600000],include_lowest=True,
#                                        labels=['<50000','>50000'] )

# %% [markdown]
# <div class="alert alert-info">Les colonnes Neighborhood, ZipCode, PropertyGFAParking ne semblent pas importantes.</div>

# %% [raw]
# df.drop(columns=["BuildingType", "Neighborhood", "ZipCode", "PropertyGFAParking"],inplace=True)

# %%
df[['TotalGHGEmissions',Target_data]].describe()
# Out:
#        TotalGHGEmissions  TotalGHGEmissions
# count        3101.000000        3101.000000
# mean           93.634028          93.634028
# std           188.738934         188.738934
# min             0.400000           0.400000
# 25%             9.650000           9.650000
# 50%            34.220000          34.220000
# 75%            94.020000          94.020000
# max          2573.750000        2573.750000

# %%
fig = plt.figure(figsize=(12, 9))

for idx,feat in enumerate([Target_data]):
    for i,tr in enumerate(['raw','log']):
        if tr == 'raw':
            ax = fig.add_subplot(2,2, (idx+i+1))
            h = ax.hist(df[feat], bins=50, color='steelblue', density=True, edgecolor='none')
            ax.set_title(feat, fontsize=10)
            ax.xaxis.set_tick_params(labelsize=7)
        else:
            ax = fig.add_subplot(2,2, (idx+i+2))
            h = ax.hist(np.log1p(df[feat]), bins=50, color='steelblue', density=True, edgecolor='none')
            ax.set_title('Log(1 + x) '+feat, fontsize=10)
            ax.xaxis.set_tick_params(labelsize=7)

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class CustomTransformerytology(BaseEstimator, TransformerMixin):
    def __init__(self):
        pass
        
    def fit(self, y, X=None):
        return self
    
    def transform(self, y, X=None):
        # Perform arbitary transformation
        return np.log1p(y)
    
    def inverse_transform(self,y, X=None):
        return np.expm1(y)

# %% [markdown]
# ### <a name="C33"><font color='teal'>3.3 Feature Engenering</font></a>

# %%
plt.figure(figsize=(12,6))
ax1 = plt.subplot(2, 2, 1)

pearson_values = df.corr()[[Target_data]]\
.sort_values(by = Target_data)\
.drop([Target_data])

kendall_values = df.corr(method = 'kendall')[[Target_data]]\
.sort_values(by = Target_data)\
.drop([Target_data])

pearson_values.rename(columns={'TotalGHGEmissions':'Pearson'})\
.join(kendall_values.rename(columns={'TotalGHGEmissions':'Kendall'}))\
.plot(y = ['Pearson','Kendall'],kind='bar',ax = ax1)

ax1.set_title(Target_data + "Brutes")
for id, val in enumerate(pearson_values[Target_data]): ax1.text(id-0.5, val, str(round(val,2)) )


    
    
ax2 = plt.subplot(2, 2, 2)

X_data = df.copy()
X_data['log_target'] = np.log1p(X_data[Target_data])

pearson_values = X_data.corr()[['log_target']]\
.sort_values(by = 'log_target')\
.drop([Target_data,'log_target'])

kendall_values = X_data.corr(method = 'kendall')[['log_target']]\
.sort_values(by = 'log_target')\
.drop([Target_data,'log_target'])

pearson_values.rename(columns={'log_target':'Pearson'})\
.join(kendall_values.rename(columns={'log_target':'Kendall'}))\
.plot(y = ['Pearson','Kendall'],kind='bar',ax = ax2)

ax2.set_title("Log" + Target_data)
for id, val in enumerate(pearson_values['log_target']): ax2.text(id-0.5, val, str(round(val,2)) )

# %%
# Score à battre
print("La correlation de perason à battre est :",round(np.max(pearson_values,axis=0)[0],2))
# Out:
# La correlation de perason à battre est : 0.5

# %% [raw]
# df['sqrt_SecondLargestPropertyUseTypeGFA'] =   np.sqrt( df["SecondLargestPropertyUseTypeGFA"] )
# df['sqrt_FloorXBuildingsXm2'] =   np.sqrt( (df["NumberofFloors"]+1) * df['PropertyGFABuilding(s)'] * df["NumberofBuildings"])
#
# # Surface total au sol de chaque Batiment
# df['SurfaceSolTotal'] = df["NumberofFloors"] * df['PropertyGFABuilding(s)']/df["NumberofBuildings"]
#
# #Nombre d'étage total par batiment
# df['NombrePieceTotal'] = df["NumberofFloors"] * df["NumberofBuildings"]
#
# # Plus
# df['SecondLargestPropertyUseTypeGFAXsqrt_FloorXBuildingsXm2'] = df["SecondLargestPropertyUseTypeGFA"] * np.sqrt( (df["NumberofFloors"]+1) * df['PropertyGFABuilding(s)'] * df["NumberofBuildings"])
#
# # creation la colonne PropertyBuilding_pourc
# df['PropertyBuilding_pourc'] = df['PropertyGFABuilding(s)']/df['PropertyGFATotal']
#
# # Taux de m2/etage
# df["Tx_m2_Floors"] = df.PropertyGFATotal/ df.NumberofFloors
#
# # Taux m2_batiment
# df["RatePerBuildings"] = df.PropertyGFATotal/ df.NumberofBuildings
#
# # Pourcentage de LargestProperty
# df["LargestProperty_m2_pourc"] = df.LargestPropertyUseTypeGFA/ df.PropertyGFATotal
#
# # Pourcentage de LargestProperty
# df["SecondLargestProperty_m2_pourc"] = df.SecondLargestPropertyUseTypeGFA/ df.PropertyGFATotal
#
# # Pourcentage de LargestProperty
# df["ThirdLargestProperty_m2_pourc"] = df.ThirdLargestPropertyUseTypeGFA/ df.PropertyGFATotal
#
#
#
# #################################################################""
# # surface total au sol habitable
# #Nombre de batiment * nombre d'etage * la surface d'un batiment
# X_a_teste['FloorXGFABuildings'] = X_a_teste['NumberofFloors'] * X_a_teste['PropertyGFABuilding(s)']
#
# # Pourcentage de surface occupé par un batiment
# # Surface occupé par le ou les batiments / Surface total
# X_a_teste['PropertyBuilding_pourc'] = X_a_teste['PropertyGFABuilding(s)']/X_a_teste['PropertyGFATotal']
#
# # Pourcentage de surface occupé par the largest propertyuse
# X_a_teste['LargestPropertyUseTypeGFA_pourc'] = X_a_teste['LargestPropertyUseTypeGFA']/X_a_teste['PropertyGFABuilding(s)']
#
# # Pourcentage de surface occupé par the Second largest propertyuse
# X_a_teste['SecondLargestPropertyUseTypeGFA_pourc'] = X_a_teste['SecondLargestPropertyUseTypeGFA']/X_a_teste['PropertyGFABuilding(s)']
#
# # Pourcentage de surface occupé par the Third largest propertyuse
# X_a_teste['ThirdLargestPropertyUseTypeGFA_pourc'] = X_a_teste['ThirdLargestPropertyUseTypeGFA']/X_a_teste['PropertyGFABuilding(s)']
#
# # Nombre de piece Total
# X_a_teste['nombreTotaldePiece'] = X_a_teste["NumberofFloors"] * X_a_teste["NumberofBuildings"]
#
# # Plus
# X_a_teste['LargestPropertyUseTypeGFAXsqrt_FloorXBuildingsXm2'] = X_a_teste["LargestPropertyUseTypeGFA"] * np.sqrt( (X_a_teste["NumberofFloors"]) * X_a_teste['PropertyGFABuilding(s)'] * df["NumberofBuildings"])
# X_a_teste['SecondLargestPropertyUseTypeGFAXsqrt_FloorXBuildingsXm2'] = X_a_teste["SecondLargestPropertyUseTypeGFA"] * np.sqrt( (X_a_teste["NumberofFloors"]) * X_a_teste['PropertyGFABuilding(s)'] * df["NumberofBuildings"])
#
# # Taux de m2 par pièce
# X_a_teste['TauxM2parPiece'] = X_a_teste.PropertyGFATotal/(X_a_teste['NumberofFloors'] * X_a_teste["NumberofBuildings"])
#
# # Taille d'une pièce
# X_a_teste["meanSizeRoom"] = X_a_teste['PropertyGFABuilding(s)'] / (X_a_teste.NumberofBuildings * X_a_teste['NumberofFloors'])
#
# # Taux de m2/etage
# X_a_teste["SurfaceParFloors"] = X_a_teste.PropertyGFATotal / X_a_teste.NumberofFloors
#
# # Taux m2_batiment
# X_a_teste["SurfaceParBuildings"] = X_a_teste.PropertyGFATotal / X_a_teste.NumberofBuildings
#
#
# # FloorXBuildingsXm2
# X_a_teste['FirstAndSecondLarg'] = ( X_a_teste['LargestPropertyUseTypeGFA'] + X_a_teste['SecondLargestPropertyUseTypeGFA'])
#
#
# # Racine carré Floor nbBuilding M2
# X_a_teste['sqrt_FloorXBuildingsXm2'] = np.log1p(np.sqrt( X_a_teste['NumberofFloors'] * X_a_teste['PropertyGFABuilding(s)'] * X_a_teste["NumberofBuildings"]))
#
# # Racine carré Surface Total Habitable
# X_a_teste['Second_First'] = np.sqrt( X_a_teste['SecondLargestPropertyUseTypeGFA'] * X_a_teste['LargestPropertyUseTypeGFA'] )

# %% [markdown]
# ### <a name="C34"><font color='teal'>3.4 Create X & y</font></a>

# %%
X = df.dropna().drop(columns = [Target_data,'TotalGHGEmissions'])#.values ENERGYSTARScore
y = df.dropna()[Target_data]#.values
X.shape , y.shape
# Out:
# ((3101, 27), (3101,))

# %%
X.head()
# Out:
#                  BuildingType PrimaryPropertyType ZipCode  \
# OSEBuildingID
# 1              NonResidential               Hotel   98101
# 2              NonResidential               Hotel   98101
# 5              NonResidential               Hotel   98101
# 8              NonResidential               Hotel   98121
# 9              NonResidential               Other   98101
#
#                CouncilDistrictCode Neighborhood LargestPropertyUseType  \
# OSEBuildingID
# 1                                7     downtown                  hotel
# 2                                7     downtown                  hotel
# 5                                7     downtown                  hotel
# 8                                7     downtown                  hotel
# 9                                7     downtown               grouping
#
#               SecondLargestPropertyUseType ThirdLargestPropertyUseType  \
# OSEBuildingID
# 1                                     void                        void
# 2                                  parking                  restaurant
# 5                                     void                        void
# 8                                  parking               swimming pool
# 9                                     void                        void
#
#                Latitude  Longitude  NumberofBuildings  NumberofFloors  \
# OSEBuildingID
# 1              47.61220 -122.33799                1.0            12.0
# 2              47.61317 -122.33393                1.0            11.0
# 5              47.61412 -122.33664                1.0            10.0
# 8              47.61375 -122.34047                1.0            18.0
# 9              47.61623 -122.33657                1.0             2.0
#
#                PropertyGFATotal  PropertyGFAParking  PropertyGFABuilding(s)  \
# OSEBuildingID
# 1                       88434.0                 0.0                 88434.0
# 2                      103566.0             15064.0                 88502.0
# 5                       61320.0                 0.0                 61320.0
# 8                      175580.0             62000.0                113580.0
# 9                       97288.0             37198.0                 60090.0
#
#                LargestPropertyUseTypeGFA  SecondLargestPropertyUseTypeGFA  \
# OSEBuildingID
# 1                                88434.0                              0.0
# 2                                83880.0                          15064.0
# 5                                61320.0                              0.0
# 8                               123445.0                          68009.0
# 9                                88830.0                              0.0
#
#                ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  NumberofRooms  \
# OSEBuildingID
# 1                                         0.0        60.000000           12.0
# 2                                      4622.0        61.000000           11.0
# 5                                         0.0        56.000000           10.0
# 8                                         0.0        75.000000           18.0
# 9                                         0.0        46.951391            2.0
#
#                NbTotalUseType   Age  dist_mean  dist_mean_CDC  \
# OSEBuildingID
# 1                         1.0  89.0   1.337395       1.273185
# 2                         3.0  20.0   1.209663       1.406095
# 5                         1.0  90.0   1.110927       1.183644
# 8                         3.0  36.0   1.219978       1.024299
# 9                         1.0  17.0   0.877805       1.044282
#
#                dist_mean_Neigh  Rate_GFABuilding   GFAperFloor
# OSEBuildingID
# 1                     0.402721          1.000000   7369.500000
# 2                     0.573195          0.854547   9415.090909
# 5                     0.617268          1.000000   6132.000000
# 8                     0.615997          0.646885   9754.444444
# 9                     0.851444          0.617651  48644.000000

# %%
y.head()
# Out:
# OSEBuildingID
# 1    249.98
# 2    295.86
# 5    286.43
# 8    505.01
# 9    301.81
# Name: TotalGHGEmissions, dtype: float64

# %% [markdown]
# ### <a name="C35"><font color='teal'>3.5 Train Test Split</font></a>

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.3, 
                                                    random_state=0)
print("Notre dataset d'entrainement est une matrice {} et la cible {}".format(X_train.shape,y_train.shape))
print("Notre dataset de test est une matrice au format {} et la cible {}".format(X_test.shape,y_test.shape) )
# Out:
# Notre dataset d'entrainement est une matrice (2170, 27) et la cible (2170,)
# Notre dataset de test est une matrice au format (931, 27) et la cible (931,)

# %%
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import PowerTransformer

for col in ['PropertyGFATotal',
       'PropertyGFAParking', 'PropertyGFABuilding(s)',
       'LargestPropertyUseTypeGFA', 'SecondLargestPropertyUseTypeGFA',
       'ThirdLargestPropertyUseTypeGFA','GFAperFloor','Longitude']:
    #tandis que Yeo-Johnson prend en charge les données positives ou négatives.
    yj = PowerTransformer(method="yeo-johnson")
    qt = QuantileTransformer(output_distribution="normal")
    
    # perform power transforms and quantile transform
    yj.fit( X_train[col].values.reshape(-1,1) )
    X_train[col+'_PTyj'] = yj.transform( X_train[col].values.reshape(-1,1) )
    X_test[col+'_PTyj'] = yj.transform( X_test[col].values.reshape(-1,1) )
    #X_test[col] = qt.fit_transform( X_test[col].values.reshape(-1,1) )

# %% [markdown]
# ### <a name="C36"><font color='teal'>3.6 Label Encoder</font></a>

# %%
df.select_dtypes(exclude=np.number).nunique()
# Out:
# BuildingType                     6
# PrimaryPropertyType             23
# ZipCode                         26
# Neighborhood                    13
# LargestPropertyUseType          39
# SecondLargestPropertyUseType    26
# ThirdLargestPropertyUseType     21
# dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer

# regrpouper les modalité qui represente moins de 10 batiment dans une super modalité

# Create an instance of One-hot-encoder
ohe = OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore') #

# Transform X_train categorical
df_cat_train = ohe.fit_transform(X_train.select_dtypes(exclude=np.number) ) 
df_cat_train = pd.DataFrame(df_cat_train,
                            columns = ohe.get_feature_names_out(),
                            index = X_train.index)

# Create X_train encoded data 
X_train_encod = pd.merge(X_train.select_dtypes(include=np.number),
                        df_cat_train, left_index=True, right_index=True) 


# Transform X_test categorical
df_cat_test = ohe.transform(X_test.select_dtypes(exclude=np.number) ) 
df_cat_test = pd.DataFrame(df_cat_test,
                           columns = ohe.get_feature_names_out(),
                           index = X_test.index)

# Create X_test encoded data 
X_test_encod = pd.merge(X_test.select_dtypes(include=np.number),
                        df_cat_test, left_index=True, right_index=True)
# Out:
# C:\Users\eleor\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:188: UserWarning: Found unknown categories in columns [4] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
X_train_encod.head()
# Out:
#                CouncilDistrictCode  Latitude  Longitude  NumberofBuildings  \
# OSEBuildingID
# 596                              2  47.55623 -122.33316                1.0
# 23215                            7  47.62477 -122.36154                1.0
# 26134                            3  47.61654 -122.32592                1.0
# 26163                            3  47.61941 -122.31304                1.0
# 21192                            1  47.55105 -122.34695                2.0
#
#                NumberofFloors  PropertyGFATotal  PropertyGFAParking  \
# OSEBuildingID
# 596                       1.0           50008.0                 0.0
# 23215                     4.0           41420.0                 0.0
# 26134                     3.0           46274.0                 0.0
# 26163                     4.0           29421.0                 0.0
# 21192                     2.0           28368.0                 0.0
#
#                PropertyGFABuilding(s)  LargestPropertyUseTypeGFA  \
# OSEBuildingID
# 596                           50008.0                    50008.0
# 23215                         41420.0                    41420.0
# 26134                         46274.0                    40282.0
# 26163                         29421.0                    29421.0
# 21192                         28368.0                    35300.0
#
#                SecondLargestPropertyUseTypeGFA  \
# OSEBuildingID
# 596                                        0.0
# 23215                                      0.0
# 26134                                   5992.0
# 26163                                  15308.0
# 21192                                   9408.0
#
#                ThirdLargestPropertyUseTypeGFA  ENERGYSTARScore  NumberofRooms  \
# OSEBuildingID
# 596                                       0.0        62.000000            1.0
# 23215                                     0.0        63.000000            4.0
# 26134                                     0.0        88.000000            3.0
# 26163                                  8796.0        90.000000            4.0
# 21192                                     0.0        66.920083            4.0
#
#                NbTotalUseType   Age  dist_mean  dist_mean_CDC  \
# OSEBuildingID
# 596                       1.0  78.0   7.540360       1.877112
# 23215                     1.0  87.0   2.006037       1.064841
# 26134                     2.0  92.0   1.066162       0.727211
# 26163                     3.0   9.0   1.709624       0.554706
# 21192                     2.0  45.0   8.166389       1.925519
#
#                dist_mean_Neigh  Rate_GFABuilding   GFAperFloor  \
# OSEBuildingID
# 596                   1.169367               1.0  50008.000000
# 23215                 1.057498               1.0  10355.000000
# 26134                 0.418217               1.0  15424.666667
# 26163                 0.626239               1.0   7355.250000
# 21192                 1.544026               1.0  14184.000000
#
#                PropertyGFATotal_PTyj  PropertyGFAParking_PTyj  \
# OSEBuildingID
# 596                         0.141273                -0.412075
# 23215                      -0.142321                -0.412075
# 26134                       0.028489                -0.412075
# 26163                      -0.750492                -0.412075
# 21192                      -0.823270                -0.412075
#
#                PropertyGFABuilding(s)_PTyj  LargestPropertyUseTypeGFA_PTyj  \
# OSEBuildingID
# 596                               0.195902                        0.276763
# 23215                            -0.090875                        0.029606
# 26134                             0.081827                       -0.008614
# 26163                            -0.705229                       -0.471850
# 21192                            -0.778694                       -0.195896
#
#                SecondLargestPropertyUseTypeGFA_PTyj  \
# OSEBuildingID
# 596                                       -0.938013
# 23215                                     -0.938013
# 26134                                      0.921605
# 26163                                      1.075142
# 21192                                      0.996414
#
#                ThirdLargestPropertyUseTypeGFA_PTyj  GFAperFloor_PTyj  \
# OSEBuildingID
# 596                                      -0.442999          1.503546
# 23215                                    -0.442999         -0.438545
# 26134                                    -0.442999          0.124448
# 26163                                     2.261940         -0.966746
# 21192                                    -0.442999          0.010421
#
#                Longitude_PTyj  BuildingType_Multifamily HR (10+)  \
# OSEBuildingID
# 596              5.384582e-15                                0.0
# 23215           -9.178769e-14                                0.0
# 26134            3.019807e-14                                0.0
# 26163            7.435719e-14                                0.0
# 21192           -4.182765e-14                                0.0
#
#                BuildingType_Multifamily LR (1-4)  \
# OSEBuildingID
# 596                                          0.0
# 23215                                        1.0
# 26134                                        1.0
# 26163                                        1.0
# 21192                                        0.0
#
#                BuildingType_Multifamily MR (5-9)  BuildingType_NonResidential  \
# OSEBuildingID
# 596                                          0.0                          1.0
# 23215                                        0.0                          0.0
# 26134                                        0.0                          0.0
# 26163                                        0.0                          0.0
# 21192                                        0.0                          1.0
#
#                BuildingType_SPS-District K-12  \
# OSEBuildingID
# 596                                       0.0
# 23215                                     0.0
# 26134                                     0.0
# 26163                                     0.0
# 21192                                     0.0
#
#                PrimaryPropertyType_High-Rise Multifamily  \
# OSEBuildingID
# 596                                                  0.0
# 23215                                                0.0
# 26134                                                0.0
# 26163                                                0.0
# 21192                                                0.0
#
#                PrimaryPropertyType_Hospital  PrimaryPropertyType_Hotel  \
# OSEBuildingID
# 596                                     0.0                        0.0
# 23215                                   0.0                        0.0
# 26134                                   0.0                        0.0
# 26163                                   0.0                        0.0
# 21192                                   0.0                        0.0
#
#                PrimaryPropertyType_K-12 School  \
# OSEBuildingID
# 596                                        0.0
# 23215                                      0.0
# 26134                                      0.0
# 26163                                      0.0
# 21192                                      0.0
#
#                PrimaryPropertyType_Laboratory  \
# OSEBuildingID
# 596                                       0.0
# 23215                                     0.0
# 26134                                     0.0
# 26163                                     0.0
# 21192                                     0.0
#
#                PrimaryPropertyType_Large Office  \
# OSEBuildingID
# 596                                         0.0
# 23215                                       0.0
# 26134                                       0.0
# 26163                                       0.0
# 21192                                       0.0
#
#                PrimaryPropertyType_Low-Rise Multifamily  \
# OSEBuildingID
# 596                                                 0.0
# 23215                                               1.0
# 26134                                               1.0
# 26163                                               1.0
# 21192                                               0.0
#
#                PrimaryPropertyType_Medical Office  \
# OSEBuildingID
# 596                                           0.0
# 23215                                         0.0
# 26134                                         0.0
# 26163                                         0.0
# 21192                                         0.0
#
#                PrimaryPropertyType_Mid-Rise Multifamily  \
# OSEBuildingID
# 596                                                 0.0
# 23215                                               0.0
# 26134                                               0.0
# 26163                                               0.0
# 21192                                               0.0
#
#                PrimaryPropertyType_Mixed Use Property  \
# OSEBuildingID
# 596                                               0.0
# 23215                                             0.0
# 26134                                             0.0
# 26163                                             0.0
# 21192                                             0.0
#
#                PrimaryPropertyType_Other  \
# OSEBuildingID
# 596                                  0.0
# 23215                                0.0
# 26134                                0.0
# 26163                                0.0
# 21192                                0.0
#
#                PrimaryPropertyType_Refrigerated Warehouse  \
# OSEBuildingID
# 596                                                   0.0
# 23215                                                 0.0
# 26134                                                 0.0
# 26163                                                 0.0
# 21192                                                 0.0
#
#                PrimaryPropertyType_Residence Hall  \
# OSEBuildingID
# 596                                           0.0
# 23215                                         0.0
# 26134                                         0.0
# 26163                                         0.0
# 21192                                         0.0
#
#                PrimaryPropertyType_Restaurant  \
# OSEBuildingID
# 596                                       0.0
# 23215                                     0.0
# 26134                                     0.0
# 26163                                     0.0
# 21192                                     0.0
#
#                PrimaryPropertyType_Retail Store  \
# OSEBuildingID
# 596                                         0.0
# 23215                                       0.0
# 26134                                       0.0
# 26163                                       0.0
# 21192                                       0.0
#
#                PrimaryPropertyType_Self-Storage Facility  \
# OSEBuildingID
# 596                                                  0.0
# 23215                                                0.0
# 26134                                                0.0
# 26163                                                0.0
# 21192                                                0.0
#
#                PrimaryPropertyType_Senior Care Community  \
# OSEBuildingID
# 596                                                  0.0
# 23215                                                0.0
# 26134                                                0.0
# 26163                                                0.0
# 21192                                                0.0
#
#                PrimaryPropertyType_Small- and Mid-Sized Office  \
# OSEBuildingID
# 596                                                        1.0
# 23215                                                      0.0
# 26134                                                      0.0
# 26163                                                      0.0
# 21192                                                      0.0
#
#                PrimaryPropertyType_Supermarket / Grocery Store  \
# OSEBuildingID
# 596                                                        0.0
# 23215                                                      0.0
# 26134                                                      0.0
# 26163                                                      0.0
# 21192                                                      0.0
#
#                PrimaryPropertyType_University  PrimaryPropertyType_Warehouse  \
# OSEBuildingID
# 596                                       0.0                            0.0
# 23215                                     0.0                            0.0
# 26134                                     0.0                            0.0
# 26163                                     0.0                            0.0
# 21192                                     0.0                            0.0
#
#                PrimaryPropertyType_Worship Facility  ZipCode_98102  \
# OSEBuildingID
# 596                                             0.0            0.0
# 23215                                           0.0            0.0
# 26134                                           0.0            0.0
# 26163                                           0.0            0.0
# 21192                                           0.0            0.0
#
#                ZipCode_98103  ZipCode_98104  ZipCode_98105  ZipCode_98106  \
# OSEBuildingID
# 596                      0.0            0.0            0.0            0.0
# 23215                    0.0            0.0            0.0            0.0
# 26134                    0.0            0.0            0.0            0.0
# 26163                    0.0            0.0            0.0            0.0
# 21192                    0.0            0.0            0.0            1.0
#
#                ZipCode_98107  ZipCode_98108  ZipCode_98109  ZipCode_98112  \
# OSEBuildingID
# 596                      0.0            0.0            0.0            0.0
# 23215                    0.0            0.0            0.0            0.0
# 26134                    0.0            0.0            0.0            0.0
# 26163                    0.0            0.0            0.0            0.0
# 21192                    0.0            0.0            0.0            0.0
#
#                ZipCode_98115  ZipCode_98116  ZipCode_98117  ZipCode_98118  \
# OSEBuildingID
# 596                      0.0            0.0            0.0            0.0
# 23215                    0.0            0.0            0.0            0.0
# 26134                    0.0            0.0            0.0            0.0
# 26163                    0.0            0.0            0.0            0.0
# 21192                    0.0            0.0            0.0            0.0
#
#                ZipCode_98119  ZipCode_98121  ZipCode_98122  ZipCode_98125  \
# OSEBuildingID
# 596                      0.0            0.0            0.0            0.0
# 23215                    1.0            0.0            0.0            0.0
# 26134                    0.0            0.0            1.0            0.0
# 26163                    0.0            0.0            0.0            0.0
# 21192                    0.0            0.0            0.0            0.0
#
#                ZipCode_98126  ZipCode_98133  ZipCode_98134  ZipCode_98136  \
# OSEBuildingID
# 596                      0.0            0.0            1.0            0.0
# 23215                    0.0            0.0            0.0            0.0
# 26134                    0.0            0.0            0.0            0.0
# 26163                    0.0            0.0            0.0            0.0
# 21192                    0.0            0.0            0.0            0.0
#
#                ZipCode_98144  ZipCode_98195  ZipCode_98199  ZipCode_grouping  \
# OSEBuildingID
# 596                      0.0            0.0            0.0               0.0
# 23215                    0.0            0.0            0.0               0.0
# 26134                    0.0            0.0            0.0               0.0
# 26163                    0.0            0.0            1.0               0.0
# 21192                    0.0            0.0            0.0               0.0
#
#                Neighborhood_central  Neighborhood_delridge  \
# OSEBuildingID
# 596                             0.0                    0.0
# 23215                           0.0                    0.0
# 26134                           0.0                    0.0
# 26163                           0.0                    0.0
# 21192                           0.0                    1.0
#
#                Neighborhood_downtown  Neighborhood_east  \
# OSEBuildingID
# 596                              0.0                0.0
# 23215                            0.0                0.0
# 26134                            0.0                1.0
# 26163                            0.0                1.0
# 21192                            0.0                0.0
#
#                Neighborhood_greater duwamish  Neighborhood_lake union  \
# OSEBuildingID
# 596                                      1.0                      0.0
# 23215                                    0.0                      0.0
# 26134                                    0.0                      0.0
# 26163                                    0.0                      0.0
# 21192                                    0.0                      0.0
#
#                Neighborhood_magnolia / queen anne  Neighborhood_north  \
# OSEBuildingID
# 596                                           0.0                 0.0
# 23215                                         1.0                 0.0
# 26134                                         0.0                 0.0
# 26163                                         0.0                 0.0
# 21192                                         0.0                 0.0
#
#                Neighborhood_northeast  Neighborhood_northwest  \
# OSEBuildingID
# 596                               0.0                     0.0
# 23215                             0.0                     0.0
# 26134                             0.0                     0.0
# 26163                             0.0                     0.0
# 21192                             0.0                     0.0
#
#                Neighborhood_southeast  Neighborhood_southwest  \
# OSEBuildingID
# 596                               0.0                     0.0
# 23215                             0.0                     0.0
# 26134                             0.0                     0.0
# 26163                             0.0                     0.0
# 21192                             0.0                     0.0
#
#                LargestPropertyUseType_bank branch  \
# OSEBuildingID
# 596                                           0.0
# 23215                                         0.0
# 26134                                         0.0
# 26163                                         0.0
# 21192                                         0.0
#
#                LargestPropertyUseType_college/university  \
# OSEBuildingID
# 596                                                  0.0
# 23215                                                0.0
# 26134                                                0.0
# 26163                                                0.0
# 21192                                                0.0
#
#                LargestPropertyUseType_data center  \
# OSEBuildingID
# 596                                           0.0
# 23215                                         0.0
# 26134                                         0.0
# 26163                                         0.0
# 21192                                         0.0
#
#                LargestPropertyUseType_distribution center  \
# OSEBuildingID
# 596                                                   0.0
# 23215                                                 0.0
# 26134                                                 0.0
# 26163                                                 0.0
# 21192                                                 1.0
#
#                LargestPropertyUseType_fitness center/health club/gym  \
# OSEBuildingID
# 596                                                              0.0
# 23215                                                            0.0
# 26134                                                            0.0
# 26163                                                            0.0
# 21192                                                            0.0
#
#                LargestPropertyUseType_grouping  \
# OSEBuildingID
# 596                                        0.0
# 23215                                      0.0
# 26134                                      0.0
# 26163                                      0.0
# 21192                                      0.0
#
#                LargestPropertyUseType_hospital (general medical & surgical)  \
# OSEBuildingID
# 596                                                                     0.0
# 23215                                                                   0.0
# 26134                                                                   0.0
# 26163                                                                   0.0
# 21192                                                                   0.0
#
#                LargestPropertyUseType_hotel  \
# OSEBuildingID
# 596                                     0.0
# 23215                                   0.0
# 26134                                   0.0
# 26163                                   0.0
# 21192                                   0.0
#
#                LargestPropertyUseType_k-12 school  \
# OSEBuildingID
# 596                                           0.0
# 23215                                         0.0
# 26134                                         0.0
# 26163                                         0.0
# 21192                                         0.0
#
#                LargestPropertyUseType_laboratory  \
# OSEBuildingID
# 596                                          0.0
# 23215                                        0.0
# 26134                                        0.0
# 26163                                        0.0
# 21192                                        0.0
#
#                LargestPropertyUseType_manufacturing/industrial plant  \
# OSEBuildingID
# 596                                                              0.0
# 23215                                                            0.0
# 26134                                                            0.0
# 26163                                                            0.0
# 21192                                                            0.0
#
#                LargestPropertyUseType_medical office  \
# OSEBuildingID
# 596                                              0.0
# 23215                                            0.0
# 26134                                            0.0
# 26163                                            0.0
# 21192                                            0.0
#
#                LargestPropertyUseType_multifamily housing  \
# OSEBuildingID
# 596                                                   0.0
# 23215                                                 1.0
# 26134                                                 1.0
# 26163                                                 1.0
# 21192                                                 0.0
#
#                LargestPropertyUseType_museum  \
# OSEBuildingID
# 596                                      0.0
# 23215                                    0.0
# 26134                                    0.0
# 26163                                    0.0
# 21192                                    0.0
#
#                LargestPropertyUseType_non-refrigerated warehouse  \
# OSEBuildingID
# 596                                                          0.0
# 23215                                                        0.0
# 26134                                                        0.0
# 26163                                                        0.0
# 21192                                                        0.0
#
#                LargestPropertyUseType_office  LargestPropertyUseType_other  \
# OSEBuildingID
# 596                                      1.0                           0.0
# 23215                                    0.0                           0.0
# 26134                                    0.0                           0.0
# 26163                                    0.0                           0.0
# 21192                                    0.0                           0.0
#
#                LargestPropertyUseType_other - education  \
# OSEBuildingID
# 596                                                 0.0
# 23215                                               0.0
# 26134                                               0.0
# 26163                                               0.0
# 21192                                               0.0
#
#                LargestPropertyUseType_other - entertainment/public assembly  \
# OSEBuildingID
# 596                                                                     0.0
# 23215                                                                   0.0
# 26134                                                                   0.0
# 26163                                                                   0.0
# 21192                                                                   0.0
#
#                LargestPropertyUseType_other - lodging/residential  \
# OSEBuildingID
# 596                                                           0.0
# 23215                                                         0.0
# 26134                                                         0.0
# 26163                                                         0.0
# 21192                                                         0.0
#
#                LargestPropertyUseType_other - mall  \
# OSEBuildingID
# 596                                            0.0
# 23215                                          0.0
# 26134                                          0.0
# 26163                                          0.0
# 21192                                          0.0
#
#                LargestPropertyUseType_other - recreation  \
# OSEBuildingID
# 596                                                  0.0
# 23215                                                0.0
# 26134                                                0.0
# 26163                                                0.0
# 21192                                                0.0
#
#                LargestPropertyUseType_other - services  \
# OSEBuildingID
# 596                                                0.0
# 23215                                              0.0
# 26134                                              0.0
# 26163                                              0.0
# 21192                                              0.0
#
#                LargestPropertyUseType_other/specialty hospital  \
# OSEBuildingID
# 596                                                        0.0
# 23215                                                      0.0
# 26134                                                      0.0
# 26163                                                      0.0
# 21192                                                      0.0
#
#                LargestPropertyUseType_parking  \
# OSEBuildingID
# 596                                       0.0
# 23215                                     0.0
# 26134                                     0.0
# 26163                                     0.0
# 21192                                     0.0
#
#                LargestPropertyUseType_refrigerated warehouse  \
# OSEBuildingID
# 596                                                      0.0
# 23215                                                    0.0
# 26134                                                    0.0
# 26163                                                    0.0
# 21192                                                    0.0
#
#                LargestPropertyUseType_repair services (vehicle, shoe, locksmith, etc)  \
# OSEBuildingID
# 596                                                                               0.0
# 23215                                                                             0.0
# 26134                                                                             0.0
# 26163                                                                             0.0
# 21192                                                                             0.0
#
#                LargestPropertyUseType_residence hall/dormitory  \
# OSEBuildingID
# 596                                                        0.0
# 23215                                                      0.0
# 26134                                                      0.0
# 26163                                                      0.0
# 21192                                                      0.0
#
#                LargestPropertyUseType_restaurant  \
# OSEBuildingID
# 596                                          0.0
# 23215                                        0.0
# 26134                                        0.0
# 26163                                        0.0
# 21192                                        0.0
#
#                LargestPropertyUseType_retail store  \
# OSEBuildingID
# 596                                            0.0
# 23215                                          0.0
# 26134                                          0.0
# 26163                                          0.0
# 21192                                          0.0
#
#                LargestPropertyUseType_self-storage facility  \
# OSEBuildingID
# 596                                                     0.0
# 23215                                                   0.0
# 26134                                                   0.0
# 26163                                                   0.0
# 21192                                                   0.0
#
#                LargestPropertyUseType_senior care community  \
# OSEBuildingID
# 596                                                     0.0
# 23215                                                   0.0
# 26134                                                   0.0
# 26163                                                   0.0
# 21192                                                   0.0
#
#                LargestPropertyUseType_social/meeting hall  \
# OSEBuildingID
# 596                                                   0.0
# 23215                                                 0.0
# 26134                                                 0.0
# 26163                                                 0.0
# 21192                                                 0.0
#
#                LargestPropertyUseType_strip mall  \
# OSEBuildingID
# 596                                          0.0
# 23215                                        0.0
# 26134                                        0.0
# 26163                                        0.0
# 21192                                        0.0
#
#                LargestPropertyUseType_supermarket/grocery store  \
# OSEBuildingID
# 596                                                         0.0
# 23215                                                       0.0
# 26134                                                       0.0
# 26163                                                       0.0
# 21192                                                       0.0
#
#                LargestPropertyUseType_urgent care/clinic/other outpatient  \
# OSEBuildingID
# 596                                                                   0.0
# 23215                                                                 0.0
# 26134                                                                 0.0
# 26163                                                                 0.0
# 21192                                                                 0.0
#
#                LargestPropertyUseType_worship facility  \
# OSEBuildingID
# 596                                                0.0
# 23215                                              0.0
# 26134                                              0.0
# 26163                                              0.0
# 21192                                              0.0
#
#                SecondLargestPropertyUseType_data center  \
# OSEBuildingID
# 596                                                 0.0
# 23215                                               0.0
# 26134                                               0.0
# 26163                                               0.0
# 21192                                               0.0
#
#                SecondLargestPropertyUseType_distribution center  \
# OSEBuildingID
# 596                                                         0.0
# 23215                                                       0.0
# 26134                                                       0.0
# 26163                                                       0.0
# 21192                                                       0.0
#
#                SecondLargestPropertyUseType_fitness center/health club/gym  \
# OSEBuildingID
# 596                                                                    0.0
# 23215                                                                  0.0
# 26134                                                                  0.0
# 26163                                                                  0.0
# 21192                                                                  0.0
#
#                SecondLargestPropertyUseType_food service  \
# OSEBuildingID
# 596                                                  0.0
# 23215                                                0.0
# 26134                                                0.0
# 26163                                                0.0
# 21192                                                0.0
#
#                SecondLargestPropertyUseType_grouping  \
# OSEBuildingID
# 596                                              0.0
# 23215                                            0.0
# 26134                                            0.0
# 26163                                            0.0
# 21192                                            0.0
#
#                SecondLargestPropertyUseType_k-12 school  \
# OSEBuildingID
# 596                                                 0.0
# 23215                                               0.0
# 26134                                               0.0
# 26163                                               0.0
# 21192                                               0.0
#
#                SecondLargestPropertyUseType_laboratory  \
# OSEBuildingID
# 596                                                0.0
# 23215                                              0.0
# 26134                                              0.0
# 26163                                              0.0
# 21192                                              0.0
#
#                SecondLargestPropertyUseType_medical office  \
# OSEBuildingID
# 596                                                    0.0
# 23215                                                  0.0
# 26134                                                  0.0
# 26163                                                  0.0
# 21192                                                  0.0
#
#                SecondLargestPropertyUseType_multifamily housing  \
# OSEBuildingID
# 596                                                         0.0
# 23215                                                       0.0
# 26134                                                       0.0
# 26163                                                       0.0
# 21192                                                       0.0
#
#                SecondLargestPropertyUseType_non-refrigerated warehouse  \
# OSEBuildingID
# 596                                                                0.0
# 23215                                                              0.0
# 26134                                                              0.0
# 26163                                                              0.0
# 21192                                                              0.0
#
#                SecondLargestPropertyUseType_office  \
# OSEBuildingID
# 596                                            0.0
# 23215                                          0.0
# 26134                                          0.0
# 26163                                          0.0
# 21192                                          1.0
#
#                SecondLargestPropertyUseType_other  \
# OSEBuildingID
# 596                                           0.0
# 23215                                         0.0
# 26134                                         0.0
# 26163                                         0.0
# 21192                                         0.0
#
#                SecondLargestPropertyUseType_other - entertainment/public assembly  \
# OSEBuildingID
# 596                                                                           0.0
# 23215                                                                         0.0
# 26134                                                                         0.0
# 26163                                                                         0.0
# 21192                                                                         0.0
#
#                SecondLargestPropertyUseType_other - recreation  \
# OSEBuildingID
# 596                                                        0.0
# 23215                                                      0.0
# 26134                                                      0.0
# 26163                                                      0.0
# 21192                                                      0.0
#
#                SecondLargestPropertyUseType_other - restaurant/bar  \
# OSEBuildingID
# 596                                                            0.0
# 23215                                                          0.0
# 26134                                                          0.0
# 26163                                                          0.0
# 21192                                                          0.0
#
#                SecondLargestPropertyUseType_other - services  \
# OSEBuildingID
# 596                                                      0.0
# 23215                                                    0.0
# 26134                                                    0.0
# 26163                                                    0.0
# 21192                                                    0.0
#
#                SecondLargestPropertyUseType_parking  \
# OSEBuildingID
# 596                                             0.0
# 23215                                           0.0
# 26134                                           1.0
# 26163                                           1.0
# 21192                                           0.0
#
#                SecondLargestPropertyUseType_repair services (vehicle, shoe, locksmith, etc)  \
# OSEBuildingID
# 596                                                                                     0.0
# 23215                                                                                   0.0
# 26134                                                                                   0.0
# 26163                                                                                   0.0
# 21192                                                                                   0.0
#
#                SecondLargestPropertyUseType_restaurant  \
# OSEBuildingID
# 596                                                0.0
# 23215                                              0.0
# 26134                                              0.0
# 26163                                              0.0
# 21192                                              0.0
#
#                SecondLargestPropertyUseType_retail store  \
# OSEBuildingID
# 596                                                  0.0
# 23215                                                0.0
# 26134                                                0.0
# 26163                                                0.0
# 21192                                                0.0
#
#                SecondLargestPropertyUseType_self-storage facility  \
# OSEBuildingID
# 596                                                           0.0
# 23215                                                         0.0
# 26134                                                         0.0
# 26163                                                         0.0
# 21192                                                         0.0
#
#                SecondLargestPropertyUseType_supermarket/grocery store  \
# OSEBuildingID
# 596                                                               0.0
# 23215                                                             0.0
# 26134                                                             0.0
# 26163                                                             0.0
# 21192                                                             0.0
#
#                SecondLargestPropertyUseType_swimming pool  \
# OSEBuildingID
# 596                                                   0.0
# 23215                                                 0.0
# 26134                                                 0.0
# 26163                                                 0.0
# 21192                                                 0.0
#
#                SecondLargestPropertyUseType_void  \
# OSEBuildingID
# 596                                          1.0
# 23215                                        1.0
# 26134                                        0.0
# 26163                                        0.0
# 21192                                        0.0
#
#                SecondLargestPropertyUseType_worship facility  \
# OSEBuildingID
# 596                                                      0.0
# 23215                                                    0.0
# 26134                                                    0.0
# 26163                                                    0.0
# 21192                                                    0.0
#
#                ThirdLargestPropertyUseType_data center  \
# OSEBuildingID
# 596                                                0.0
# 23215                                              0.0
# 26134                                              0.0
# 26163                                              0.0
# 21192                                              0.0
#
#                ThirdLargestPropertyUseType_financial office  \
# OSEBuildingID
# 596                                                     0.0
# 23215                                                   0.0
# 26134                                                   0.0
# 26163                                                   0.0
# 21192                                                   0.0
#
#                ThirdLargestPropertyUseType_fitness center/health club/gym  \
# OSEBuildingID
# 596                                                                   0.0
# 23215                                                                 0.0
# 26134                                                                 0.0
# 26163                                                                 0.0
# 21192                                                                 0.0
#
#                ThirdLargestPropertyUseType_food service  \
# OSEBuildingID
# 596                                                 0.0
# 23215                                               0.0
# 26134                                               0.0
# 26163                                               0.0
# 21192                                               0.0
#
#                ThirdLargestPropertyUseType_grouping  \
# OSEBuildingID
# 596                                             0.0
# 23215                                           0.0
# 26134                                           0.0
# 26163                                           0.0
# 21192                                           0.0
#
#                ThirdLargestPropertyUseType_medical office  \
# OSEBuildingID
# 596                                                   0.0
# 23215                                                 0.0
# 26134                                                 0.0
# 26163                                                 0.0
# 21192                                                 0.0
#
#                ThirdLargestPropertyUseType_multifamily housing  \
# OSEBuildingID
# 596                                                        0.0
# 23215                                                      0.0
# 26134                                                      0.0
# 26163                                                      0.0
# 21192                                                      0.0
#
#                ThirdLargestPropertyUseType_non-refrigerated warehouse  \
# OSEBuildingID
# 596                                                               0.0
# 23215                                                             0.0
# 26134                                                             0.0
# 26163                                                             0.0
# 21192                                                             0.0
#
#                ThirdLargestPropertyUseType_office  \
# OSEBuildingID
# 596                                           0.0
# 23215                                         0.0
# 26134                                         0.0
# 26163                                         1.0
# 21192                                         0.0
#
#                ThirdLargestPropertyUseType_other  \
# OSEBuildingID
# 596                                          0.0
# 23215                                        0.0
# 26134                                        0.0
# 26163                                        0.0
# 21192                                        0.0
#
#                ThirdLargestPropertyUseType_other - entertainment/public assembly  \
# OSEBuildingID
# 596                                                                          0.0
# 23215                                                                        0.0
# 26134                                                                        0.0
# 26163                                                                        0.0
# 21192                                                                        0.0
#
#                ThirdLargestPropertyUseType_other - restaurant/bar  \
# OSEBuildingID
# 596                                                           0.0
# 23215                                                         0.0
# 26134                                                         0.0
# 26163                                                         0.0
# 21192                                                         0.0
#
#                ThirdLargestPropertyUseType_parking  \
# OSEBuildingID
# 596                                            0.0
# 23215                                          0.0
# 26134                                          0.0
# 26163                                          0.0
# 21192                                          0.0
#
#                ThirdLargestPropertyUseType_personal services (health/beauty, dry cleaning, etc)  \
# OSEBuildingID
# 596                                                                                         0.0
# 23215                                                                                       0.0
# 26134                                                                                       0.0
# 26163                                                                                       0.0
# 21192                                                                                       0.0
#
#                ThirdLargestPropertyUseType_pre-school/daycare  \
# OSEBuildingID
# 596                                                       0.0
# 23215                                                     0.0
# 26134                                                     0.0
# 26163                                                     0.0
# 21192                                                     0.0
#
#                ThirdLargestPropertyUseType_restaurant  \
# OSEBuildingID
# 596                                               0.0
# 23215                                             0.0
# 26134                                             0.0
# 26163                                             0.0
# 21192                                             0.0
#
#                ThirdLargestPropertyUseType_retail store  \
# OSEBuildingID
# 596                                                 0.0
# 23215                                               0.0
# 26134                                               0.0
# 26163                                               0.0
# 21192                                               0.0
#
#                ThirdLargestPropertyUseType_social/meeting hall  \
# OSEBuildingID
# 596                                                        0.0
# 23215                                                      0.0
# 26134                                                      0.0
# 26163                                                      0.0
# 21192                                                      0.0
#
#                ThirdLargestPropertyUseType_swimming pool  \
# OSEBuildingID
# 596                                                  0.0
# 23215                                                0.0
# 26134                                                0.0
# 26163                                                0.0
# 21192                                                0.0
#
#                ThirdLargestPropertyUseType_void
# OSEBuildingID
# 596                                         1.0
# 23215                                       1.0
# 26134                                       1.0
# 26163                                       0.0
# 21192                                       1.0

# %%
X_train_encod.shape,X_test_encod.shape
# Out:
# ((2170, 174), (931, 174))

# %% [markdown]
# ### <a name="C37"><font color='teal'>3.7 Scaling</font></a>

# %%
plt.figure(figsize=(12,6))
ax1 = plt.subplot(1, 2, 1)
df.corr()[['TotalGHGEmissions']].sort_index()\
.drop(['TotalGHGEmissions']).plot(kind='bar',ax = ax1)
ax1.set_title("Corrélation de Pearson")


ax2 = plt.subplot(1, 2, 2)
df.corr(method = 'kendall')[['TotalGHGEmissions']].sort_index()\
.drop(['TotalGHGEmissions']).plot(kind='bar',ax = ax2)
ax2.set_title("Corrélation de Kendall");

# %% [markdown]
# ##### <font color='teal'>3.7.1 Scaling All DataSet Encoding cat Data and Numeric Data</font>

# %%
from sklearn.preprocessing import RobustScaler # StandardScaler, MinMaxScaler,Normalizer
Scaler_encod = RobustScaler().fit(X_train_encod)
X_train_encod_scaled = Scaler_encod.transform(X_train_encod)
X_test_encod_scaled = Scaler_encod.transform(X_test_encod)

# %% [markdown]
# ##### <font color='teal'>3.7.1 Scaling All DataSet WHITOUT ENERGYSTARScore </font>

# %%
from sklearn.preprocessing import StandardScaler # MinMaxScaler,Normalizer
Scaler_encodWESS = StandardScaler().fit(X_train_encod.drop(columns=['ENERGYSTARScore']))
X_train_encod_scaledWESS = Scaler_encodWESS.transform( X_train_encod.drop(columns=['ENERGYSTARScore']) )
X_test_encod_scaledWESS = Scaler_encodWESS.transform( X_test_encod.drop(columns=['ENERGYSTARScore']) )

# %% [markdown]
# ##### <font color='teal'>3.7.3 Scaling Reduct DataSet</font>

# %% [markdown]
# ##### <font color='teal'>Feature Selection</font>

# %% [raw]
# https://machinelearningmastery.com/feature-selection-with-real-and-categorical-data/

# %% [markdown]
# <font color='green'> RFE : Élimination récursive des fonctionnalités </font>

# %% [raw]
# %%time
# from sklearn.feature_selection import RFECV
# from sklearn.model_selection import KFold
# from sklearn.ensemble import RandomForestRegressor
#
# min_features_to_select = 1  # Minimum number of features to consider
# reg = RandomForestRegressor(max_depth=5)
# #reg = LinearRegression()
# cv = KFold(3)
#
# rfecv = RFECV(
#     estimator=reg,
#     step=1,
#     cv=cv,
#     scoring="r2",
#     min_features_to_select=min_features_to_select,
#     n_jobs=11,
# )
# rfecv.fit(pd.DataFrame(X_train_encod_scaled,columns=Scaler_encod.feature_names_in_), y_train)
#
# print(f"Optimal number of features: {rfecv.n_features_}")

# %% [raw]
# rfecv.get_feature_names_out()

# %% [raw]
# %%time
# import matplotlib.pyplot as plt
#
# n_scores = len(rfecv.cv_results_["mean_test_score"])
# plt.figure()
# plt.xlabel("Number of features selected")
# plt.ylabel("Mean test rmse")
# plt.errorbar(
#     range(min_features_to_select, n_scores + min_features_to_select),
#     rfecv.cv_results_["mean_test_score"],
#     yerr=rfecv.cv_results_["std_test_score"],
# )
# plt.title("Recursive Feature Elimination \nwith correlated features")
# plt.show()

# %% [raw]
# %%time
# from sklearn.feature_selection import RFECV
# from sklearn.model_selection import KFold
# from sklearn.ensemble import GradientBoostingRegressor
#
# min_features_to_select = 1  # Minimum number of features to consider
# reg = GradientBoostingRegressor()
#
# cv = KFold(3)
#
# rfecvGB = RFECV(
#     estimator=reg,
#     step=1,
#     cv=cv,
#     scoring="r2",
#     min_features_to_select=min_features_to_select,
#     n_jobs=11,
# )
# rfecvGB.fit(pd.DataFrame(X_train_encod_scaled,columns=Scaler_encod.feature_names_in_), y_train)
#
# print(f"Optimal number of features: {rfecvGB.n_features_}")

# %% [raw]
# rfecvGB.get_feature_names_out()

# %% [raw]
# %%time
# import matplotlib.pyplot as plt
#
# n_scores = len(rfecvGB.cv_results_["mean_test_score"])
# plt.figure()
# plt.xlabel("Number of features selected")
# plt.ylabel("Mean test rmse")
# plt.errorbar(
#     range(min_features_to_select, n_scores + min_features_to_select),
#     rfecvGB.cv_results_["mean_test_score"],
#     yerr=rfecvGB.cv_results_["std_test_score"],
# )
# plt.title("Recursive Feature Elimination \nwith correlated features")
# plt.show()

# %% [markdown]
# #### <div class="alert alert-info"><font color='teal'> Liste des colonnes conservées</font></div>

# %% [raw]
# if len(rfecvGB.get_feature_names_out()) < len(rfecv.get_feature_names_out()):
#     col_cons = rfecvGB.get_feature_names_out()
# elif len(rfecvGB.get_feature_names_out()) >= len(rfecv.get_feature_names_out()):
#     col_cons = rfecv.get_feature_names_out()
# col_cons=col_cons.tolist()
# col_cons

# %% [raw]
# from sklearn.preprocessing import StandardScaler,RobustScaler # MinMaxScaler,Normalizer
#
#
# X_train_reduct = X_train_encod[col_cons]
# X_test_reduct = X_test_encod[col_cons]
#
# ScalerReduct = RobustScaler().fit(X_train_reduct)
# X_train_reduct_scaled = ScalerReduct.transform(X_train_reduct)
# X_test_reduct_scaled = ScalerReduct.transform(X_test_reduct)

# %% [markdown]
# <hr>

# %% [markdown]
# </br>

# %% [markdown]
# # <a name="C4"><font color='green'>**Partie 4 : Modélisation**</font></a>

# %% [markdown]
# ### <a name="C41"><font color='green'>4.1 Dummy Estimator</font></a>

# %%
# %%time
warnings.filterwarnings(action='ignore')

#y numerique
naifMean = dummy.DummyRegressor(strategy='mean')
naifMedian = dummy.DummyRegressor(strategy='median')

meanNaifCV = cross_val_score(naifMean,X_train_encod_scaled,np.log1p(y_train),scoring="neg_mean_squared_error")
medianNaifCV = cross_val_score(naifMedian,X_train_encod_scaled,np.log1p(y_train),scoring="neg_mean_squared_error")
meanNaifCVr2 = cross_val_score(naifMean,X_train_encod_scaled,np.log1p(y_train),scoring="r2")

print( "Le score neg_mean_squared_error du DummyRegressor strategy 'mean' est {}".format(meanNaifCV.mean()))
print( "Le score neg_mean_squared_error du DummyRegressor strategy 'median' est {}".format( medianNaifCV.mean() ))

print( "Le score r2 du mean DummyRegressor est {} et le std est {}".format(np.mean(meanNaifCVr2),np.std(meanNaifCVr2)))
# Out:
# Le score neg_mean_squared_error du DummyRegressor strategy 'mean' est -1.9384033825824087
# Le score neg_mean_squared_error du DummyRegressor strategy 'median' est -1.940848002639963
# Le score r2 du mean DummyRegressor est -0.0026554833549848667 et le std est 0.0037545467983800583
# CPU times: total: 31.2 ms
# Wall time: 39.4 ms

# %% [markdown]
# ### <a name="C42"><font color='green'>4.2 Model type Reducted </font></a>

# %%
def compute_score(reg, X, y):
    xval = cross_val_score(reg, X, y, cv = 5,scoring='r2')
    return np.mean(xval)

# %%
import time
def compute_score_time(reg, X, y):
    # get starting time
    start = time.time()
    # compute r2 score
    xval = cross_val_score(reg, X, y, cv = 5,scoring='r2')
    # get the execution time
    elapsed_time_lc=(time.time()-start)
    return {'R2 score':round(np.mean(xval),5),'Time':elapsed_time_lc}

# %%
import time
from sklearn.model_selection import cross_validate
def compute_cross_validate_score_time(reg, X, y):
    # get starting time
    start = time.time()
    # compute r2 score
    xval = cross_validate(reg, X, y, cv = 5,scoring=['r2','neg_mean_squared_error'])
    # get the execution time
    elapsed_time_lc=(time.time()-start)
    return {'Time':elapsed_time_lc,
            'R2 mean score':round(np.mean(xval['test_r2']),5),
            'R2 std score':round(np.std(xval['test_r2']),5),
            'RMSE mean score':-round(np.mean(xval['test_neg_mean_squared_error']),5),
            'RMSE std score':round(np.std(xval['test_neg_mean_squared_error']),5),
           }

# %% [raw]
# model_type_reducted = dict()
#
# # y => np.log1p
# model_type_reducted['LinearRegression'] = compute_cross_validate_score_time(LinearRegression(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['RandomForest'] = compute_cross_validate_score_time(RandomForestRegressor(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['Ridge'] = compute_cross_validate_score_time(Ridge(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['Lasso'] = compute_cross_validate_score_time(Lasso(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['ElasticNet'] = compute_cross_validate_score_time(ElasticNet(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['Bagging'] = compute_cross_validate_score_time(BaggingRegressor(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['AdaBoost'] = compute_cross_validate_score_time(AdaBoostRegressor(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['HistGradientBoosting'] = compute_cross_validate_score_time(HistGradientBoostingRegressor(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['GradientBoosting'] = compute_cross_validate_score_time(GradientBoostingRegressor(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['LightGBM'] = compute_cross_validate_score_time(LGBMRegressor(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['xgboost'] = compute_cross_validate_score_time(xgb.XGBRegressor(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['svr_linear'] = compute_cross_validate_score_time(LinearSVR(), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['svr_sigmoid'] = compute_cross_validate_score_time(SVR(kernel='sigmoid'), X_train_reduct_scaled,np.log1p(y_train))
# model_type_reducted['svr_rbf'] = compute_cross_validate_score_time(SVR(kernel='rbf'), X_train_reduct_scaled,np.log1p(y_train))
#
# #y brute sans tranformation
# model_type_reducted['svr_poly'] = compute_cross_validate_score_time(SVR(kernel='poly'), X_train_reduct_scaled,y_train)
# model_type_reducted['kernel_ridge'] = compute_cross_validate_score_time(kernel_ridge.KernelRidge(), X_train_reduct_scaled,y_train)

# %%
model_type_reducted = dict()

# y => np.log1p
model_type_reducted['LinearRegression'] = compute_cross_validate_score_time(LinearRegression(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['RandomForest'] = compute_cross_validate_score_time(RandomForestRegressor(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['Ridge'] = compute_cross_validate_score_time(Ridge(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['Lasso'] = compute_cross_validate_score_time(Lasso(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['ElasticNet'] = compute_cross_validate_score_time(ElasticNet(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['Bagging'] = compute_cross_validate_score_time(BaggingRegressor(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['AdaBoost'] = compute_cross_validate_score_time(AdaBoostRegressor(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['HistGradientBoosting'] = compute_cross_validate_score_time(HistGradientBoostingRegressor(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['GradientBoosting'] = compute_cross_validate_score_time(GradientBoostingRegressor(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['LightGBM'] = compute_cross_validate_score_time(LGBMRegressor(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['xgboost'] = compute_cross_validate_score_time(xgb.XGBRegressor(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['svr_linear'] = compute_cross_validate_score_time(LinearSVR(), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['svr_sigmoid'] = compute_cross_validate_score_time(SVR(kernel='sigmoid'), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['svr_rbf'] = compute_cross_validate_score_time(SVR(kernel='rbf'), X_train_encod_scaled,np.log1p(y_train))

#y brute sans tranformation
model_type_reducted['svr_poly'] = compute_cross_validate_score_time(SVR(kernel='poly'), X_train_encod_scaled,np.log1p(y_train))
model_type_reducted['kernel_ridge'] = compute_cross_validate_score_time(kernel_ridge.KernelRidge(), X_train_encod_scaled,np.log1p(y_train))

# %%
pd.DataFrame(model_type_reducted).T
# Out:
#                            Time  R2 mean score  R2 std score  RMSE mean score  \
# LinearRegression       0.106450     -590.98923    1183.15328       1132.96272
# RandomForest          11.995111        0.67924       0.00377          0.62011
# Ridge                  0.051051        0.60554       0.01662          0.76178
# Lasso                  0.043175        0.09515       0.01463          1.74855
# ElasticNet             0.026230        0.20563       0.02103          1.53453
# Bagging                1.327631        0.64201       0.00691          0.69172
# AdaBoost               2.667270        0.53793       0.01320          0.89286
# HistGradientBoosting  10.111127        0.68742       0.01048          0.60404
# GradientBoosting       5.052930        0.69088       0.00681          0.59761
# LightGBM               0.658324        0.68767       0.00939          0.60395
# xgboost                1.918416        0.68025       0.01552          0.61791
# svr_linear             0.687165     -168.02903     250.41488        336.78171
# svr_sigmoid            1.434568     -106.58074      14.51307        207.65312
# svr_rbf                1.755502        0.12367       0.01381          1.69418
# svr_poly              13.435637       -1.90854       3.69405          5.39223
# kernel_ridge           0.407899        0.59605       0.01579          0.78027
#
#                       RMSE std score
# LinearRegression          2264.32858
# RandomForest                 0.02495
# Ridge                        0.02519
# Lasso                        0.05120
# ElasticNet                   0.03868
# Bagging                      0.01952
# AdaBoost                     0.03240
# HistGradientBoosting         0.02560
# GradientBoosting             0.02635
# LightGBM                     0.03201
# xgboost                      0.03441
# svr_linear                 505.13171
# svr_sigmoid                 26.62758
# svr_rbf                      0.06983
# svr_poly                     6.61373
# kernel_ridge                 0.02830

# %%
# VotingRegressor
VotingRegressor_er = VotingRegressor([('gb', GradientBoostingRegressor()), 
                                      ('rf', RandomForestRegressor()), 
                                      ('LightGbm', LGBMRegressor()), 
                                      ('HistGBoost',HistGradientBoostingRegressor()), 
                                      ('xgb',xgb.XGBRFRegressor()),
                                      ('Ridge',Ridge())]
                                    )

model_type_reducted['VotingRegressor'] = compute_cross_validate_score_time(VotingRegressor_er, X_train_encod_scaled,np.log1p(y_train))



# StackingRegressor
from sklearn.ensemble import StackingRegressor
estimators = [('gb', GradientBoostingRegressor()), 
              ('rf', RandomForestRegressor()), 
              ('LightGbm', LGBMRegressor()),
              ('HistGBoost',HistGradientBoostingRegressor()),
              ('xgb',xgb.XGBRFRegressor()),
              ('Ridge',Ridge())
             ]
reg = StackingRegressor(
    estimators=estimators,
    final_estimator=RandomForestRegressor(n_estimators=1000,max_depth=5,random_state=42)
)

model_type_reducted['StackingRegressor'] = compute_cross_validate_score_time(reg, X_train_encod_scaled,np.log1p(y_train))

# %%
pd.DataFrame(model_type_reducted).T.sort_values(by = ['R2 mean score'] , ascending = False)
# Out:
#                             Time  R2 mean score  R2 std score  \
# VotingRegressor        29.992536        0.70325       0.00596
# StackingRegressor     169.099051        0.69969       0.01249
# GradientBoosting        5.052930        0.69088       0.00681
# LightGBM                0.658324        0.68767       0.00939
# HistGradientBoosting   10.111127        0.68742       0.01048
# xgboost                 1.918416        0.68025       0.01552
# RandomForest           11.995111        0.67924       0.00377
# Bagging                 1.327631        0.64201       0.00691
# Ridge                   0.051051        0.60554       0.01662
# kernel_ridge            0.407899        0.59605       0.01579
# AdaBoost                2.667270        0.53793       0.01320
# ElasticNet              0.026230        0.20563       0.02103
# svr_rbf                 1.755502        0.12367       0.01381
# Lasso                   0.043175        0.09515       0.01463
# svr_poly               13.435637       -1.90854       3.69405
# svr_sigmoid             1.434568     -106.58074      14.51307
# svr_linear              0.687165     -168.02903     250.41488
# LinearRegression        0.106450     -590.98923    1183.15328
#
#                       RMSE mean score  RMSE std score
# VotingRegressor               0.57358         0.02218
# StackingRegressor             0.58005         0.02161
# GradientBoosting              0.59761         0.02635
# LightGBM                      0.60395         0.03201
# HistGradientBoosting          0.60404         0.02560
# xgboost                       0.61791         0.03441
# RandomForest                  0.62011         0.02495
# Bagging                       0.69172         0.01952
# Ridge                         0.76178         0.02519
# kernel_ridge                  0.78027         0.02830
# AdaBoost                      0.89286         0.03240
# ElasticNet                    1.53453         0.03868
# svr_rbf                       1.69418         0.06983
# Lasso                         1.74855         0.05120
# svr_poly                      5.39223         6.61373
# svr_sigmoid                 207.65312        26.62758
# svr_linear                  336.78171       505.13171
# LinearRegression           1132.96272      2264.32858

# %% [markdown]
# ### <a name="C43"><font color='green'>4.3 Model type Whitout ENERGYSTARScore </font></a>

# %%
model_type_WESS = dict()

# y => np.log1p
model_type_WESS['LinearRegression'] = compute_cross_validate_score_time(LinearRegression(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['RandomForest'] = compute_cross_validate_score_time(RandomForestRegressor(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['Ridge'] = compute_cross_validate_score_time(Ridge(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['Lasso'] = compute_cross_validate_score_time(Lasso(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['ElasticNet'] = compute_cross_validate_score_time(ElasticNet(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['Bagging'] = compute_cross_validate_score_time(BaggingRegressor(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['AdaBoost'] = compute_cross_validate_score_time(AdaBoostRegressor(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['HistGradientBoosting'] = compute_cross_validate_score_time(HistGradientBoostingRegressor(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['GradientBoosting'] = compute_cross_validate_score_time(GradientBoostingRegressor(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['LightGBM'] = compute_cross_validate_score_time(LGBMRegressor(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['xgboost'] = compute_cross_validate_score_time(xgb.XGBRegressor(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['svr_linear'] = compute_cross_validate_score_time(LinearSVR(), X_train_encod_scaledWESS,np.log1p(y_train))
model_type_WESS['svr_rbf'] = compute_cross_validate_score_time(SVR(kernel='rbf'), X_train_encod_scaledWESS,np.log1p(y_train))

#y brute sans tranformation
model_type_WESS['svr_poly'] = compute_cross_validate_score_time(SVR(kernel='poly'), X_train_encod_scaledWESS,y_train)
model_type_WESS['kernel_ridge'] = compute_cross_validate_score_time(kernel_ridge.KernelRidge(), X_train_encod_scaledWESS,y_train)
model_type_WESS['svr_sigmoid'] = compute_cross_validate_score_time(SVR(kernel='sigmoid'), X_train_encod_scaledWESS,y_train)

# %% [raw]
# model_type_WESS

# %%
# VotingRegressor
VotingRegressor_er = VotingRegressor([('gb', GradientBoostingRegressor()), 
                                      ('rf', RandomForestRegressor()), 
                                      ('LightGbm', LGBMRegressor()), 
                                      ('AdaBoost', AdaBoostRegressor()),
                                      ('HistGBoost',HistGradientBoostingRegressor()), 
                                      ('xgb',xgb.XGBRFRegressor()),
                                      ('Ridge',Ridge())]
                                    )

model_type_WESS['VotingRegressor'] = compute_cross_validate_score_time(VotingRegressor_er, X_train_encod_scaledWESS,np.log1p(y_train))



# StackingRegressor
from sklearn.ensemble import StackingRegressor
estimators = [('gb', GradientBoostingRegressor()), 
              ('rf', RandomForestRegressor()), 
              ('LightGbm', LGBMRegressor()), 
              ('AdaBoost', AdaBoostRegressor()),
              ('HistGBoost',HistGradientBoostingRegressor()), 
              ('xgb',xgb.XGBRFRegressor()),
              ('Ridge',Ridge())]
reg = StackingRegressor(
    estimators=estimators,
    final_estimator=RandomForestRegressor(n_estimators=1000,max_depth=5,random_state=42)
)

model_type_WESS['StackingRegressor'] = compute_cross_validate_score_time(reg, X_train_encod_scaledWESS,np.log1p(y_train))

# %%
pd.DataFrame(model_type_WESS).T.sort_values(by = ['R2 mean score'] , ascending = False)
# Out:
#                             Time  R2 mean score  R2 std score  \
# VotingRegressor        31.699499   6.305800e-01  1.174000e-02
# StackingRegressor     182.343332   6.283400e-01  1.282000e-02
# GradientBoosting        4.921521   6.242600e-01  1.213000e-02
# RandomForest           11.761006   6.190700e-01  1.748000e-02
# HistGradientBoosting    9.394636   6.013900e-01  1.582000e-02
# LightGBM                0.749791   5.970300e-01  1.743000e-02
# xgboost                 1.827695   5.893300e-01  1.116000e-02
# Bagging                 1.297056   5.823600e-01  1.537000e-02
# Ridge                   0.031244   5.554200e-01  1.451000e-02
# svr_rbf                 1.656251   5.546500e-01  1.148000e-02
# svr_linear              2.171753   5.136800e-01  2.712000e-02
# AdaBoost                2.561899   4.804700e-01  2.349000e-02
# ElasticNet              0.031246   2.109500e-01  6.550000e-03
# svr_sigmoid             1.421565   6.119000e-02  2.033000e-02
# svr_poly                1.171628   4.957000e-02  7.584000e-02
# Lasso                   0.031629  -2.660000e-03  3.750000e-03
# kernel_ridge            0.390507  -1.542895e+02  1.908895e+02
# LinearRegression        0.080572  -1.498787e+23  2.927970e+23
#
#                       RMSE mean score  RMSE std score
# VotingRegressor          7.137200e-01    2.476000e-02
# StackingRegressor        7.181000e-01    2.804000e-02
# GradientBoosting         7.262600e-01    3.336000e-02
# RandomForest             7.359100e-01    3.479000e-02
# HistGradientBoosting     7.702800e-01    3.621000e-02
# LightGBM                 7.784900e-01    3.406000e-02
# xgboost                  7.934700e-01    2.630000e-02
# Bagging                  8.067300e-01    2.793000e-02
# Ridge                    8.585100e-01    1.427000e-02
# svr_rbf                  8.604200e-01    2.524000e-02
# svr_linear               9.394800e-01    5.205000e-02
# AdaBoost                 1.003300e+00    3.762000e-02
# ElasticNet               1.525380e+00    5.756000e-02
# svr_sigmoid              3.596722e+04    8.705399e+03
# svr_poly                 3.607409e+04    8.322530e+03
# Lasso                    1.938400e+00    7.454000e-02
# kernel_ridge             6.405919e+06    7.981015e+06
# LinearRegression         2.952047e+23    5.770113e+23

# %% [raw]
# pd.DataFrame(model_type_WESS).T.sort_values(by=['R2 mean score'],ascending=False).drop(columns=['Time']).plot(kind="bar")

# %% [raw]
# pd.DataFrame(model_type_reducted).T.rename(columns={'R2 score':'R2 score Reduct','Time':'Time Reduct'})\
# .join(pd.DataFrame(model_type_Num).T.rename(columns={'R2 score':'R2 score Num','Time':'Time Num'}))\
# .join(pd.DataFrame(model_type_WESS).T.rename(columns={'R2 score':'R2 score All','Time':'Time All'}))\
# .join(pd.DataFrame(model_type_AllWESS).T.rename(columns={'R2 score':'R2 score AllWESS','Time':'Time AllWESS'}))

# %%
'ENERGYSTARScore' in Scaler_encod.feature_names_in_
# Out:
# True

# %%
'ENERGYSTARScore' in Scaler_encodWESS.feature_names_in_
# Out:
# False

# %%
'SiteEnergyUseWN(kBtu)' in Scaler_encodWESS.feature_names_in_
# Out:
# False

# %%
'TotalGHGEmissions' in Scaler_encodWESS.feature_names_in_
# Out:
# False

# %% [markdown]
# ### <a name="C45"><font color='green'>4.5 Benchmark</font></a>

# %%
# Init inner and outer loop
inner_cv = KFold(n_splits=3,shuffle=True,random_state=0)
outer_cv = KFold(n_splits=3,shuffle=True,random_state=1)

# %%
from sklearn.model_selection import cross_validate

def do_cross_validation_upgrade(clf,X,y, print_model=False):
    cv = cross_validate(clf, X, y, scoring=('r2', 'neg_mean_squared_error'), cv=outer_cv)
    
    scores_neg_mean_squared_error = ' + '.join(f'{s:.2f}' for s in cv["test_neg_mean_squared_error"])
    scores_r2 = ' + '.join(f'{s:.2f}' for s in cv["test_r2"])
    
    mean_r2 = cv["test_r2"].mean()
    mean_nRMSE = cv["test_neg_mean_squared_error"].mean()
    
    msg_r2 = f'Cross-validated r2: ({scores_r2}) / 3 = {mean_r2:.4f}'
    msg_nRMSE = f'Cross-validated rmse: ({scores_neg_mean_squared_error}) / 3 = {mean_nRMSE:.4f}'
    
    if print_model:
        msg_nRMSE = f'{clf}:\n\t{msg_nRMSE}\n'
        msg_r2 = f'{clf}:\n\t{msg_r2}\n'
    
    print(msg_nRMSE)
    print('\n')
    print(msg_r2)
    
def do_cross_validation(clf,X,y, print_model=False):
    cv = cross_validate(clf, X, y, scoring=('r2', 'neg_mean_squared_error'), cv=outer_cv)
    scores = ' + '.join(f'{s:.2f}' for s in cv["test_score"])
    mean_ = cv["test_score"].mean()
    msg = f'Cross-validated rmse: ({scores}) / 3 = {mean_:.4f}'
    
    if print_model:
        msg = f'{clf}:\n\t{msg}\n'
    
    print(msg)

# %% [markdown]
# <font color='red'> 4.3.Data non Residentiel</font>

# %%
# Index non Residentiel
IdxTrainNonRes = ['Multifamily' not in x for x in X_train.BuildingType]
IdxTestNonRes = ['Multifamily' not in x for x in X_test.BuildingType]

# X data non residentiel
X_train_encod_scaledNonRes = X_train_encod_scaled[IdxTrainNonRes]
X_test_encod_scaledNonRes = X_test_encod_scaled[IdxTestNonRes]

# Y data non residentiel
y_trainNonRes = y_train[IdxTrainNonRes]
y_testNonRes = y_test[IdxTestNonRes]

# %%
# Avons nous tous batiments non résidentiels
X_train_encod_scaledNonRes[:,0].size + X_test_encod_scaledNonRes[:,0].size == X.loc[['Multifamily' not in x for x in X.BuildingType]].shape[0]
# Out:
# True

# %% [markdown]
# <font color='red'> 4.3.1. RandomForestRegressor</font>

# %%
RandomForestRegressor().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [raw]
# %%time
# from sklearn.ensemble import RandomForestRegressor
#
# # p = X_train.shape[1]#nombre de variable
#
# ###### random forest inner loop
# rf_grid = GridSearchCV(RandomForestRegressor(random_state=0),
#                        param_grid={'n_estimators': [100,250,500],
#                                    'criterion' : ['squared_error', 'absolute_error'],
#                                    'max_depth' : [None,3,5,10],
#                                    'max_features' : [1.0,'auto', 'sqrt', 'log2',int(X_train_encod_scaled.shape[1]/3)],
#                                   },
#                        cv=inner_cv,n_jobs= 11,scoring='neg_root_mean_squared_error'
#                       )
# # random forest outer loop
# print('Resultat y Brute:')
# do_cross_validation_upgrade(rf_grid,X_train_reduct_scaled, y_train, print_model=False)
# print('_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_')
# print('Resultat log1p(y):')
# do_cross_validation_upgrade(rf_grid,X_train_reduct_scaled, np.log1p(y_train), print_model=False)

# %% [raw]
# res = rf_grid.fit(X_train_encod_scaled, np.log1p(y_train))
# # Print the model parameters of the best model
# print(res.best_params_)

# %% [markdown]
# <font color='red'>4.3.7. Gradient Boosting Regressor </font>

# %%
# %%time
from sklearn.ensemble import GradientBoostingRegressor

params_grid_gb = {'n_estimators': [5,100,200, 500],
                  'loss' : ['squared_error', 'absolute_error', 'huber'],
                  'learning_rate' : [0.1,0.2,0.5,1],
                 }

###### Gradient Boosting Regressor inner loop
gb_grid = GridSearchCV(GradientBoostingRegressor(random_state=0), 
                       param_grid = params_grid_gb,
                       cv=inner_cv, 
                       n_jobs=4,
                       scoring='neg_root_mean_squared_error')

# Gradient Boosting Regressor outer loop
do_cross_validation_upgrade(gb_grid,X_train_encod_scaledWESS, np.log1p(y_train), print_model=True)
print('_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_')
print('Resultat log1p(y):')
do_cross_validation_upgrade(gb_grid,X_train_encod_scaled, np.log1p(y_train), print_model=True)
# Out:
# GridSearchCV(cv=KFold(n_splits=3, random_state=0, shuffle=True),
#              estimator=GradientBoostingRegressor(random_state=0), n_jobs=4,
#              param_grid={'learning_rate': [0.1, 0.2, 0.5, 1],
#                          'loss': ['squared_error', 'absolute_error', 'huber'],
#                          'n_estimators': [5, 100, 200, 500]},
#              scoring='neg_root_mean_squared_error'):
# 	Cross-validated rmse: (-0.71 + -0.73 + -0.76) / 3 = -0.7346
#
#
#
# GridSearchCV(cv=KFold(n_splits=3, random_state=0, shuffle=True),
#              estimator=GradientBoostingRegressor(random_state=0), n_jobs=4,
#              param_grid={'learning_rate': [0.1, 0.2, 0.5, 1],
#                          'loss': ['squared_error', 'absolute_error', 'huber'],
#                          'n_estimators': [5, 100, 200, 500]},
#              scoring='neg_root_mean_squared_error'):
# 	Cross-validated r2: (0.63 + 0.62 + 0.61) / 3 = 0.6204
#
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Resultat log1p(y):
# GridSearchCV(cv=KFold(n_splits=3, random_state=0, shuffle=True),
#              estimator=GradientBoostingRegressor(random_state=0), n_jobs=4,
#              param_grid={'learning_rate': [0.1, 0.2, 0.5, 1],
#                          'loss': ['squared_error', 'absolute_error', 'huber'],
#                          'n_estimators': [5, 100, 200, 500]},
#              scoring='neg_root_mean_squared_error'):
# 	Cross-validated rmse: (-0.58 + -0.59 + -0.65) / 3 = -0.6071
#
#
#
# GridSearchCV(cv=KFold(n_splits=3, random_state=0, shuffle=True),
#              estimator=GradientBoostingRegressor(random_state=0), n_jobs=4,
#              param_grid={'learning_rate': [0.1, 0.2, 0.5, 1],
#                          'loss': ['squared_error', 'absolute_error', 'huber'],
#                          'n_estimators': [5, 100, 200, 500]},
#              scoring='neg_root_mean_squared_error'):
# 	Cross-validated r2: (0.70 + 0.69 + 0.67) / 3 = 0.6864
#
# CPU times: total: 8.56 s
# Wall time: 6min 5s

# %%
#r2
(0.6864 - 0.6204)/0.6204
# Out:
# 0.10638297872340435

# %%
#RMSE
(0.6071 - 0.7346)/0.7346
# Out:
# -0.17356384426899

# %%
# %time
res = gb_grid.fit(X_train_encod_scaled, np.log1p(y_train))
# Print the model parameters of the best model
print(res.best_params_)
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# {'learning_rate': 0.1, 'loss': 'huber', 'n_estimators': 200}

# %%
# Entrainement du modele
#best_modelGB = GradientBoostingRegressor(**res.best_params_).fit(X_train_encod_scaled, np.log1p(y_train))

# predict with best param
from sklearn.metrics import r2_score
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,20))
#xes = axes.flatten()

sns.scatterplot(x= res.best_estimator_.predict(X_train_encod_scaled), y = np.log1p(y_train),ax=axes[0,0])
axes[0,0].set_title('data train log ' + str(r2_score(np.log1p(y_train),res.best_estimator_.predict(X_train_encod_scaled))) )
axes[0,0].plot(np.log1p(y_train),np.log1p(y_train),'r')

sns.scatterplot(x= res.best_estimator_.predict(X_test_encod_scaled), y = np.log1p(y_test),ax=axes[0,1])
axes[0,1].set_title('data test log ' + str(r2_score(np.log1p(y_test),res.best_estimator_.predict(X_test_encod_scaled))) )
axes[0,1].plot(np.log1p(y_test),np.log1p(y_test),'r')

# transformation inverse
sns.scatterplot(x= np.expm1(res.best_estimator_.predict(X_train_encod_scaled)), y = y_train,ax=axes[1,0])
axes[1,0].set_title('data train ' + str(r2_score(y_train,np.expm1(res.best_estimator_.predict(X_train_encod_scaled))) ))
axes[1,0].plot(y_train,y_train,'r')

sns.scatterplot(x= np.expm1(res.best_estimator_.predict(X_test_encod_scaled)), y = y_test,ax=axes[1,1])
axes[1,1].set_title('data test ' + str(r2_score(y_test,np.expm1(res.best_estimator_.predict(X_test_encod_scaled))) ) )
axes[1,1].plot(y_test,y_test,'r');

# %%
from sklearn.metrics import mean_squared_error,r2_score

score_er = dict()
score_er['rmse log + train']= mean_squared_error( np.log1p(y_train), res.best_estimator_.predict(X_train_encod_scaled), squared=True )
score_er['rmse log + test']= mean_squared_error( np.log1p(y_test), res.best_estimator_.predict(X_test_encod_scaled), squared=True )

score_er['rmse train']= mean_squared_error( y_train, np.expm1(res.best_estimator_.predict(X_train_encod_scaled)), squared=True )
score_er['rmse test']= mean_squared_error(y_test, np.expm1(res.best_estimator_.predict(X_test_encod_scaled)), squared=True) 

score_er['r2 log + train']= r2_score(np.log1p(y_train), res.best_estimator_.predict(X_train_encod_scaled) )
score_er['r2 log + test']= r2_score( np.log1p(y_test), res.best_estimator_.predict(X_test_encod_scaled)  )

score_er['r2 train']= r2_score( y_train, np.expm1(res.best_estimator_.predict(X_train_encod_scaled)) )
score_er['r2 test']= r2_score( y_test, np.expm1(res.best_estimator_.predict(X_test_encod_scaled))) 

pd.DataFrame(score_er,index=['RMSE'])
# Out:
#       rmse log + train  rmse log + test   rmse train    rmse test  \
# RMSE          0.357778         0.596161  5796.270477  12263.82492
#
#       r2 log + train  r2 log + test  r2 train  r2 test
# RMSE        0.815245       0.682288  0.848145   0.5861

# %%
###################  Feature Importance  ###################
# cf https://mljar.com/blog/feature-importance-in-random-forest/
import time
import numpy as np

start_time = time.time()
importances = res.best_estimator_.feature_importances_
#std = np.std([tree.feature_importances_ for tree in res.best_estimator_.estimators_], axis=0)
elapsed_time = time.time() - start_time

print(f"Elapsed time to compute the importances: {elapsed_time:.3f} seconds")

X_data = pd.DataFrame({'Colonnes' : Scaler_encod.feature_names_in_, 
                       'Importances' : res.best_estimator_.feature_importances_})

plt.figure(figsize = (12,12))

X_data.sort_values(by = 'Importances',ascending=False) .head(25).plot(kind = 'bar',x = 'Colonnes' )
#plt.barh(Scaler_encod.feature_names_in_, res.best_estimator_.feature_importances_);
# Out:
# Elapsed time to compute the importances: 0.004 seconds
# <AxesSubplot:xlabel='Colonnes'>

# %%
result = pd.DataFrame(res.best_estimator_.feature_importances_,index=Scaler_encod.feature_names_in_,
             columns=['Importance'])\
.sort_values(by ='Importance', ascending=False).reset_index()

result.rename({'index': 'Colonnes'}, axis='columns',inplace=True)
result
# Out:
#                                                                              Colonnes  \
# 0                                                      LargestPropertyUseTypeGFA_PTyj
# 1                                                                    PropertyGFATotal
# 2                                                           LargestPropertyUseTypeGFA
# 3                                                                     ENERGYSTARScore
# 4                                                                                 Age
# 5                                                               PropertyGFATotal_PTyj
# 6                                            PrimaryPropertyType_Low-Rise Multifamily
# 7                                          LargestPropertyUseType_multifamily housing
# 8                                                              PropertyGFABuilding(s)
# 9                                    LargestPropertyUseType_supermarket/grocery store
# 10                                                       LargestPropertyUseType_hotel
# 11                                                        PropertyGFABuilding(s)_PTyj
# 12                                                                        GFAperFloor
# 13                                                                          dist_mean
# 14                                                                    dist_mean_Neigh
# 15                                                                           Latitude
# 16                                                                   GFAperFloor_PTyj
# 17                                                        BuildingType_NonResidential
# 18                                                                      NumberofRooms
# 19                                                      LargestPropertyUseType_office
# 20                                                      PrimaryPropertyType_Warehouse
# 21                                                          PrimaryPropertyType_Other
# 22                                                                     NumberofFloors
# 23                                                                      dist_mean_CDC
# 24                                               SecondLargestPropertyUseTypeGFA_PTyj
# 25                                    PrimaryPropertyType_Small- and Mid-Sized Office
# 26                                                    SecondLargestPropertyUseTypeGFA
# 27                                                                     NbTotalUseType
# 28                                                                     Longitude_PTyj
# 29                                          LargestPropertyUseType_other - recreation
# 30                                          PrimaryPropertyType_Senior Care Community
# 31                                                  BuildingType_Multifamily LR (1-4)
# 32                                                  LargestPropertyUseType_restaurant
# 33                                                                   Rate_GFABuilding
# 34                                                ThirdLargestPropertyUseTypeGFA_PTyj
# 35                                                 LargestPropertyUseType_k-12 school
# 36                                                                          Longitude
# 37                                                 LargestPropertyUseType_data center
# 38                                                 LargestPropertyUseType_bank branch
# 39                                                     ThirdLargestPropertyUseTypeGFA
# 40                                                              Neighborhood_downtown
# 41                                                     PrimaryPropertyType_Laboratory
# 42                                  LargestPropertyUseType_non-refrigerated warehouse
# 43                                                  LargestPropertyUseType_laboratory
# 44                                                                      ZipCode_98108
# 45                                    PrimaryPropertyType_Supermarket / Grocery Store
# 46                                                                      ZipCode_98199
# 47                                          PrimaryPropertyType_Self-Storage Facility
# 48                                                 ThirdLargestPropertyUseType_office
# 49                                                                 PropertyGFAParking
# 50                                                  BuildingType_Multifamily HR (10+)
# 51                                                                  Neighborhood_east
# 52                                       LargestPropertyUseType_senior care community
# 53                                                                      ZipCode_98119
# 54                                         LargestPropertyUseType_distribution center
# 55                                                      LargestPropertyUseType_museum
# 56                                                                      ZipCode_98117
# 57                                                            PropertyGFAParking_PTyj
# 58                                                       PrimaryPropertyType_Hospital
# 59                                          ThirdLargestPropertyUseType_swimming pool
# 60                                                    PrimaryPropertyType_K-12 School
# 61                                                                      ZipCode_98122
# 62                                                  SecondLargestPropertyUseType_void
# 63                             SecondLargestPropertyUseType_supermarket/grocery store
# 64                                                SecondLargestPropertyUseType_office
# 65                                                   PrimaryPropertyType_Large Office
# 66                       LargestPropertyUseType_hospital (general medical & surgical)
# 67                                                 SecondLargestPropertyUseType_other
# 68                                                                      ZipCode_98116
# 69                       LargestPropertyUseType_other - entertainment/public assembly
# 70                                         ThirdLargestPropertyUseType_medical office
# 71                                                     LargestPropertyUseType_parking
# 72                                                      Neighborhood_greater duwamish
# 73                                                     PrimaryPropertyType_Restaurant
# 74                                          SecondLargestPropertyUseType_retail store
# 75                                          SecondLargestPropertyUseType_food service
# 76                                                             Neighborhood_northeast
# 77   ThirdLargestPropertyUseType_personal services (health/beauty, dry cleaning, etc)
# 78                                    LargestPropertyUseType_residence hall/dormitory
# 79                                                                      ZipCode_98107
# 80                                                LargestPropertyUseType_other - mall
# 81                                               ThirdLargestPropertyUseType_grouping
# 82                                              SecondLargestPropertyUseType_grouping
# 83                                             PrimaryPropertyType_Mixed Use Property
# 84                                                                      ZipCode_98109
# 85                                          PrimaryPropertyType_High-Rise Multifamily
# 86                                         SecondLargestPropertyUseType_swimming pool
# 87                                         LargestPropertyUseType_social/meeting hall
# 88                                                          PrimaryPropertyType_Hotel
# 89                                                LargestPropertyUseType_retail store
# 90                                                 Neighborhood_magnolia / queen anne
# 91                                            LargestPropertyUseType_other - services
# 92                                           ThirdLargestPropertyUseType_food service
# 93                  ThirdLargestPropertyUseType_other - entertainment/public assembly
# 94                                                                CouncilDistrictCode
# 95                                                                      ZipCode_98104
# 96                                               SecondLargestPropertyUseType_parking
# 97                                                     BuildingType_SPS-District K-12
# 98                                                   ThirdLargestPropertyUseType_void
# 99                                                             Neighborhood_southwest
# 100                                                                  ZipCode_grouping
# 101                                              PrimaryPropertyType_Worship Facility
# 102                                                              Neighborhood_central
# 103                                                           Neighborhood_lake union
# 104                                                            Neighborhood_northwest
# 105                                                   LargestPropertyUseType_grouping
# 106                                           ThirdLargestPropertyUseType_data center
# 107                                     SecondLargestPropertyUseType_worship facility
# 108                                                    PrimaryPropertyType_University
# 109                                                                     ZipCode_98102
# 110                                SecondLargestPropertyUseType_self-storage facility
# 111                                           SecondLargestPropertyUseType_restaurant
# 112                                                                     ZipCode_98103
# 113                        ThirdLargestPropertyUseType_fitness center/health club/gym
# 114      SecondLargestPropertyUseType_repair services (vehicle, shoe, locksmith, etc)
# 115                                                                     ZipCode_98105
# 116                                     SecondLargestPropertyUseType_other - services
# 117                               SecondLargestPropertyUseType_other - restaurant/bar
# 118                                   SecondLargestPropertyUseType_other - recreation
# 119                SecondLargestPropertyUseType_other - entertainment/public assembly
# 120                                      ThirdLargestPropertyUseType_financial office
# 121                                        PrimaryPropertyType_Refrigerated Warehouse
# 122                                                  PrimaryPropertyType_Retail Store
# 123                                               ThirdLargestPropertyUseType_parking
# 124                                                                 NumberofBuildings
# 125                                   ThirdLargestPropertyUseType_social/meeting hall
# 126                                          ThirdLargestPropertyUseType_retail store
# 127                                            ThirdLargestPropertyUseType_restaurant
# 128                                    ThirdLargestPropertyUseType_pre-school/daycare
# 129                                                 BuildingType_Multifamily MR (5-9)
# 130                                ThirdLargestPropertyUseType_other - restaurant/bar
# 131                                                PrimaryPropertyType_Residence Hall
# 132                                                PrimaryPropertyType_Medical Office
# 133                                                 ThirdLargestPropertyUseType_other
# 134                                          PrimaryPropertyType_Mid-Rise Multifamily
# 135                            ThirdLargestPropertyUseType_non-refrigerated warehouse
# 136                                   ThirdLargestPropertyUseType_multifamily housing
# 137                                                                     ZipCode_98112
# 138                                                                     ZipCode_98106
# 139                                       SecondLargestPropertyUseType_medical office
# 140                           SecondLargestPropertyUseType_non-refrigerated warehouse
# 141                                LargestPropertyUseType_other - lodging/residential
# 142                                                                     ZipCode_98136
# 143            LargestPropertyUseType_repair services (vehicle, shoe, locksmith, etc)
# 144                                     LargestPropertyUseType_refrigerated warehouse
# 145                                                                     ZipCode_98144
# 146                                   LargestPropertyUseType_other/specialty hospital
# 147                                                                     ZipCode_98195
# 148                                                             Neighborhood_delridge
# 149                                  SecondLargestPropertyUseType_multifamily housing
# 150                                          LargestPropertyUseType_other - education
# 151                                                      LargestPropertyUseType_other
# 152                                                            Neighborhood_southeast
# 153                                             LargestPropertyUseType_medical office
# 154                             LargestPropertyUseType_manufacturing/industrial plant
# 155                                         LargestPropertyUseType_college/university
# 156                                                                     ZipCode_98134
# 157                                                                     ZipCode_98133
# 158                                      LargestPropertyUseType_self-storage facility
# 159                                                                     ZipCode_98126
# 160                                                                     ZipCode_98125
# 161                                                 LargestPropertyUseType_strip mall
# 162                                                                     ZipCode_98121
# 163                        LargestPropertyUseType_urgent care/clinic/other outpatient
# 164                                           LargestPropertyUseType_worship facility
# 165                                          SecondLargestPropertyUseType_data center
# 166                                  SecondLargestPropertyUseType_distribution center
# 167                       SecondLargestPropertyUseType_fitness center/health club/gym
# 168                                                                     ZipCode_98118
# 169                                                                     ZipCode_98115
# 170                                          SecondLargestPropertyUseType_k-12 school
# 171                                           SecondLargestPropertyUseType_laboratory
# 172                             LargestPropertyUseType_fitness center/health club/gym
# 173                                                                Neighborhood_north
#
#        Importance
# 0    1.466553e-01
# 1    1.227739e-01
# 2    1.175829e-01
# 3    1.120914e-01
# 4    1.079349e-01
# 5    8.758883e-02
# 6    6.563659e-02
# 7    3.215093e-02
# 8    1.949949e-02
# 9    1.362465e-02
# 10   1.356666e-02
# 11   1.351141e-02
# 12   1.174195e-02
# 13   1.042636e-02
# 14   9.256105e-03
# 15   8.706907e-03
# 16   8.622965e-03
# 17   7.819187e-03
# 18   6.459402e-03
# 19   4.768324e-03
# 20   4.565605e-03
# 21   4.513615e-03
# 22   4.487160e-03
# 23   4.205525e-03
# 24   3.223376e-03
# 25   2.852898e-03
# 26   2.599236e-03
# 27   2.591891e-03
# 28   2.529388e-03
# 29   2.494789e-03
# 30   2.365157e-03
# 31   2.282353e-03
# 32   2.112937e-03
# 33   2.085656e-03
# 34   1.954915e-03
# 35   1.822332e-03
# 36   1.689218e-03
# 37   1.625765e-03
# 38   1.501418e-03
# 39   1.444651e-03
# 40   1.395228e-03
# 41   1.378594e-03
# 42   1.369246e-03
# 43   1.271839e-03
# 44   1.167952e-03
# 45   1.084844e-03
# 46   1.074029e-03
# 47   9.416782e-04
# 48   9.011138e-04
# 49   8.448971e-04
# 50   8.433483e-04
# 51   8.107985e-04
# 52   7.670624e-04
# 53   7.027956e-04
# 54   6.945353e-04
# 55   6.586805e-04
# 56   6.122324e-04
# 57   6.109551e-04
# 58   6.054435e-04
# 59   5.752112e-04
# 60   5.687128e-04
# 61   5.306193e-04
# 62   5.110984e-04
# 63   4.760995e-04
# 64   4.735367e-04
# 65   4.733653e-04
# 66   4.205953e-04
# 67   3.340294e-04
# 68   3.220001e-04
# 69   2.959613e-04
# 70   2.725391e-04
# 71   2.559245e-04
# 72   2.328150e-04
# 73   2.323551e-04
# 74   1.807397e-04
# 75   1.787362e-04
# 76   1.729578e-04
# 77   1.699837e-04
# 78   1.602956e-04
# 79   1.512413e-04
# 80   1.495953e-04
# 81   1.414863e-04
# 82   1.404835e-04
# 83   1.386679e-04
# 84   1.291407e-04
# 85   1.228649e-04
# 86   1.223223e-04
# 87   1.213918e-04
# 88   1.212210e-04
# 89   1.080688e-04
# 90   9.848418e-05
# 91   9.223048e-05
# 92   8.138771e-05
# 93   7.679449e-05
# 94   7.592055e-05
# 95   5.749435e-05
# 96   4.673926e-05
# 97   4.325980e-05
# 98   2.644106e-05
# 99   5.258928e-06
# 100  4.378243e-06
# 101  3.254998e-06
# 102  1.852300e-06
# 103  9.872392e-07
# 104  1.629269e-07
# 105  0.000000e+00
# 106  0.000000e+00
# 107  0.000000e+00
# 108  0.000000e+00
# 109  0.000000e+00
# 110  0.000000e+00
# 111  0.000000e+00
# 112  0.000000e+00
# 113  0.000000e+00
# 114  0.000000e+00
# 115  0.000000e+00
# 116  0.000000e+00
# 117  0.000000e+00
# 118  0.000000e+00
# 119  0.000000e+00
# 120  0.000000e+00
# 121  0.000000e+00
# 122  0.000000e+00
# 123  0.000000e+00
# 124  0.000000e+00
# 125  0.000000e+00
# 126  0.000000e+00
# 127  0.000000e+00
# 128  0.000000e+00
# 129  0.000000e+00
# 130  0.000000e+00
# 131  0.000000e+00
# 132  0.000000e+00
# 133  0.000000e+00
# 134  0.000000e+00
# 135  0.000000e+00
# 136  0.000000e+00
# 137  0.000000e+00
# 138  0.000000e+00
# 139  0.000000e+00
# 140  0.000000e+00
# 141  0.000000e+00
# 142  0.000000e+00
# 143  0.000000e+00
# 144  0.000000e+00
# 145  0.000000e+00
# 146  0.000000e+00
# 147  0.000000e+00
# 148  0.000000e+00
# 149  0.000000e+00
# 150  0.000000e+00
# 151  0.000000e+00
# 152  0.000000e+00
# 153  0.000000e+00
# 154  0.000000e+00
# 155  0.000000e+00
# 156  0.000000e+00
# 157  0.000000e+00
# 158  0.000000e+00
# 159  0.000000e+00
# 160  0.000000e+00
# 161  0.000000e+00
# 162  0.000000e+00
# 163  0.000000e+00
# 164  0.000000e+00
# 165  0.000000e+00
# 166  0.000000e+00
# 167  0.000000e+00
# 168  0.000000e+00
# 169  0.000000e+00
# 170  0.000000e+00
# 171  0.000000e+00
# 172  0.000000e+00
# 173  0.000000e+00

# %% [markdown]
# <font color='red'>4.3.7.2 LightGBM </font>

# %%
# %%time
from sklearn.linear_model import LinearRegression

# p = X_train.shape[1]#nombre de variable

###### random forest inner loop
LightGbm_grid = GridSearchCV(LGBMRegressor(n_jobs= -2), 
                       param_grid={'learning_rate':[0.07552619413921881,0.1,],  
                                    'colsample_bytree': [0.5,1.0,],
                                    'subsample': [0.6633806094241483,1.0,],
                                    'reg_alpha': [0.0,0.05,], 
                                    'reg_lambda': [0,0.05],
                                    'num_leaves':[26,31,36,] ,  
                                    #'n_estimators':[100,1000]
                                  },
                       cv=inner_cv,n_jobs= 1,scoring='neg_root_mean_squared_error'
                      )
# random forest outer loop
print('Resultat y SANS NRJSTARScore:')
do_cross_validation_upgrade(LightGbm_grid,X_train_encod_scaledWESS, np.log1p(y_train), print_model=False)
print('_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_')
print('Resultat AVEC NRJSTARScore log1p(y):')
do_cross_validation_upgrade(LightGbm_grid,X_train_encod_scaled, np.log1p(y_train), print_model=False)
# Out:
# Resultat y SANS NRJSTARScore:
# Cross-validated rmse: (-0.76 + -0.76 + -0.79) / 3 = -0.7717
#
#
# Cross-validated r2: (0.60 + 0.61 + 0.60) / 3 = 0.6012
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Resultat AVEC NRJSTARScore log1p(y):
# Cross-validated rmse: (-0.62 + -0.62 + -0.65) / 3 = -0.6311
#
#
# Cross-validated r2: (0.67 + 0.68 + 0.67) / 3 = 0.6739
# CPU times: total: 25min 54s
# Wall time: 3min 34s

# %%
resLGbm = LightGbm_grid.fit(X_train_encod_scaled, np.log1p(y_train))
# Print the model parameters of the best model
print(resLGbm.best_params_)
# Out:
# {'colsample_bytree': 0.5, 'learning_rate': 0.07552619413921881, 'num_leaves': 26, 'reg_alpha': 0.05, 'reg_lambda': 0.05, 'subsample': 0.6633806094241483}

# %%
# Entrainement du modele LightGbm

# predict with best param
from sklearn.metrics import r2_score
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,20))
#xes = axes.flatten()

sns.scatterplot(x= resLGbm.best_estimator_.predict(X_train_encod_scaled), y = np.log1p(y_train),ax=axes[0,0])
axes[0,0].set_title('data train log ' + str(r2_score(np.log1p(y_train),resLGbm.best_estimator_.predict(X_train_encod_scaled))) )
axes[0,0].plot(np.log1p(y_train),np.log1p(y_train),'r')

sns.scatterplot(x= resLGbm.best_estimator_.predict(X_test_encod_scaled), y = np.log1p(y_test),ax=axes[0,1])
axes[0,1].set_title('data test log ' + str(r2_score(np.log1p(y_test),resLGbm.best_estimator_.predict(X_test_encod_scaled))) )
axes[0,1].plot(np.log1p(y_test),np.log1p(y_test),'r')

# transformation inverse
sns.scatterplot(x= np.expm1(resLGbm.best_estimator_.predict(X_train_encod_scaled)), y = y_train,ax=axes[1,0])
axes[1,0].set_title('data train log ' + str(r2_score(y_train,np.expm1(resLGbm.best_estimator_.predict(X_train_encod_scaled))) ))
axes[1,0].plot(y_train,y_train,'r')

sns.scatterplot(x= np.expm1(resLGbm.best_estimator_.predict(X_test_encod_scaled)), y = y_test,ax=axes[1,1])
axes[1,1].set_title('data test log ' + str(r2_score(y_test,np.expm1(resLGbm.best_estimator_.predict(X_test_encod_scaled))) ) )
axes[1,1].plot(y_test,y_test,'r');

# %%
from sklearn.metrics import mean_squared_error,r2_score

score_er = dict()
score_er['rmse log + train']= mean_squared_error( np.log1p(y_train),resLGbm.best_estimator_.predict(X_train_encod_scaled), squared=True )
score_er['rmse log + test']= mean_squared_error( np.log1p(y_test),resLGbm.best_estimator_.predict(X_test_encod_scaled), squared=True )

score_er['rmse train']= mean_squared_error( y_train,np.expm1(resLGbm.best_estimator_.predict(X_train_encod_scaled)), squared=True )
score_er['rmse test']= mean_squared_error(  y_test,np.expm1(resLGbm.best_estimator_.predict(X_test_encod_scaled)),squared=True) 

score_er['r2 log + train']= r2_score( np.log1p(y_train), resLGbm.best_estimator_.predict(X_train_encod_scaled) )
score_er['r2 log + test']= r2_score( np.log1p(y_test), resLGbm.best_estimator_.predict(X_test_encod_scaled) )

score_er['r2 train']= r2_score(y_train, np.expm1(resLGbm.best_estimator_.predict(X_train_encod_scaled)) )
score_er['r2 test']= r2_score(y_test, np.expm1(resLGbm.best_estimator_.predict(X_test_encod_scaled)) ) 

pd.DataFrame(score_er,index=['RMSE'])
# Out:
#       rmse log + train  rmse log + test   rmse train     rmse test  \
# RMSE          0.240512         0.620271  7650.122744  14529.300477
#
#       r2 log + train  r2 log + test  r2 train   r2 test
# RMSE        0.875801       0.669439  0.799576  0.509641

# %% [markdown]
# <font color='red'>4.3.8.3 Stacking </font>

# %%
reg = StackingRegressor(
    estimators=estimators,
    final_estimator=RandomForestRegressor(n_estimators=1000,max_depth=5,random_state=42)
)

# %%
# VotingRegressor
StackingRegressor_er = StackingRegressor([('gb', GradientBoostingRegressor(**res.best_params_)), 
                                      ('rf', RandomForestRegressor()), 
                                      ('LightGbm', LGBMRegressor(**resLGbm.best_params_)), 
                                      ('HistGBoost',HistGradientBoostingRegressor()), 
                                      ('xgb',xgb.XGBRFRegressor()),
                                      ],
    final_estimator=RandomForestRegressor(n_estimators=500,max_depth=5,random_state=42)
                                    )

StackingRegressor_er.fit(X_train_encod_scaled, np.log1p(y_train))
# Out:
# StackingRegressor(estimators=[('gb',
#                                GradientBoostingRegressor(loss='huber',
#                                                          n_estimators=200)),
#                               ('rf', RandomForestRegressor()),
#                               ('LightGbm',
#                                LGBMRegressor(colsample_bytree=0.5,
#                                              learning_rate=0.07552619413921881,
#                                              num_leaves=26, reg_alpha=0.05,
#                                              reg_lambda=0.05,
#                                              subsample=0.6633806094241483)),
#                               ('HistGBoost', HistGradientBoostingRegressor()),
#                               ('xgb',
#                                XGBRFRegressor...
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               n_estimators=100, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               objective='reg:squarederror',
#                                               predictor=None, random_state=None,
#                                               reg_alpha=None,
#                                               scale_pos_weight=None,
#                                               tree_method=None,
#                                               validate_parameters=None,
#                                               verbosity=None))],
#                   final_estimator=RandomForestRegressor(max_depth=5,
#                                                         n_estimators=500,
#                                                         random_state=42))

# %%
# Entrainement du modele

# predict with best param
from sklearn.metrics import r2_score
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15,20))
#xes = axes.flatten()

sns.scatterplot(x= StackingRegressor_er.predict(X_train_encod_scaled), y = np.log1p(y_train),ax=axes[0,0])
axes[0,0].set_title('data train log ' + str(r2_score(np.log1p(y_train),StackingRegressor_er.predict(X_train_encod_scaled))) )
axes[0,0].plot(np.log1p(y_train),np.log1p(y_train),'r')

sns.scatterplot(x=StackingRegressor_er.predict(X_test_encod_scaled), y = np.log1p(y_test),ax=axes[0,1])
axes[0,1].set_title('data test log ' + str(r2_score(np.log1p(y_test),StackingRegressor_er.predict(X_test_encod_scaled))) )
axes[0,1].plot(np.log1p(y_test),np.log1p(y_test),'r')

# transformation inverse
sns.scatterplot(x= np.expm1(StackingRegressor_er.predict(X_train_encod_scaled)), y = y_train,ax=axes[1,0])
axes[1,0].set_title('data train ' + str(r2_score(y_train,np.expm1(StackingRegressor_er.predict(X_train_encod_scaled))) ))
axes[1,0].plot(y_train,y_train,'r')

sns.scatterplot(x= np.expm1(StackingRegressor_er.predict(X_test_encod_scaled)), y = y_test,ax=axes[1,1])
axes[1,1].set_title('data test ' + str(r2_score(y_test,np.expm1(StackingRegressor_er.predict(X_test_encod_scaled))) ) )
axes[1,1].plot(y_test,y_test,'r')

# %%
from sklearn.metrics import mean_squared_error,r2_score

score_er = dict()
score_er['rmse log + train']= mean_squared_error( np.log1p(y_train),StackingRegressor_er.predict(X_train_encod_scaled), squared=True )
score_er['rmse log + test']= mean_squared_error( np.log1p(y_test),StackingRegressor_er.predict(X_test_encod_scaled), squared=True )

score_er['rmse train']= mean_squared_error( y_train,np.expm1(StackingRegressor_er.predict(X_train_encod_scaled)), squared=True )
score_er['rmse test']= mean_squared_error(  y_test,np.expm1(StackingRegressor_er.predict(X_test_encod_scaled)),squared=True) 

score_er['r2 log + train']= r2_score( np.log1p(y_train), StackingRegressor_er.predict(X_train_encod_scaled) )
score_er['r2 log + test']= r2_score( np.log1p(y_test), StackingRegressor_er.predict(X_test_encod_scaled) )

score_er['r2 train']= r2_score( y_train, np.expm1(StackingRegressor_er.predict(X_train_encod_scaled))  )
score_er['r2 test']= r2_score( y_test, np.expm1(StackingRegressor_er.predict(X_test_encod_scaled)) ) 

pd.DataFrame(score_er,index=['RMSE'])
# Out:
#       rmse log + train  rmse log + test   rmse train     rmse test  \
# RMSE          0.218888         0.591884  7560.125924  13153.148882
#
#       r2 log + train  r2 log + test  r2 train   r2 test
# RMSE        0.886967       0.684567  0.801934  0.556086

# %% [markdown]
# ### Non residensiel

# %%
# Stacking
from sklearn.metrics import mean_squared_error,r2_score

score_er = dict()
score_er['rmse log + train']= mean_squared_error( np.log1p(y_trainNonRes),StackingRegressor_er.predict(X_train_encod_scaledNonRes), squared=True )
score_er['rmse log + test']= mean_squared_error( np.log1p(y_testNonRes),StackingRegressor_er.predict(X_test_encod_scaledNonRes), squared=True )

score_er['rmse train']= mean_squared_error( y_trainNonRes,np.expm1(StackingRegressor_er.predict(X_train_encod_scaledNonRes)), squared=True )
score_er['rmse test']= mean_squared_error(  y_testNonRes,np.expm1(StackingRegressor_er.predict(X_test_encod_scaledNonRes)),squared=True) 

score_er['r2 log + train']= r2_score( np.log1p(y_trainNonRes), StackingRegressor_er.predict(X_train_encod_scaledNonRes) )
score_er['r2 log + test']= r2_score( np.log1p(y_testNonRes), StackingRegressor_er.predict(X_test_encod_scaledNonRes) )

score_er['r2 train']= r2_score( y_trainNonRes, np.expm1(StackingRegressor_er.predict(X_train_encod_scaledNonRes))  )
score_er['r2 test']= r2_score( y_testNonRes, np.expm1(StackingRegressor_er.predict(X_test_encod_scaledNonRes)) ) 

pd.DataFrame(score_er,index=['RMSE'])
# Out:
#       rmse log + train  rmse log + test    rmse train     rmse test  \
# RMSE          0.220817         0.642706  12904.865964  22416.749247
#
#       r2 log + train  r2 log + test  r2 train   r2 test
# RMSE        0.882834       0.657178  0.789855  0.551604

# %%
# Gradient boost
from sklearn.metrics import mean_squared_error,r2_score

score_er = dict()
score_er['rmse log + train']= mean_squared_error( np.log1p(y_trainNonRes), res.best_estimator_.predict(X_train_encod_scaledNonRes), squared=True )
score_er['rmse log + test']= mean_squared_error( np.log1p(y_testNonRes), res.best_estimator_.predict(X_test_encod_scaledNonRes), squared=True )

score_er['rmse train']= mean_squared_error( y_trainNonRes, np.expm1(res.best_estimator_.predict(X_train_encod_scaledNonRes)), squared=True )
score_er['rmse test']= mean_squared_error(y_testNonRes, np.expm1(res.best_estimator_.predict(X_test_encod_scaledNonRes)), squared=True) 

score_er['r2 log + train']= r2_score(np.log1p(y_trainNonRes), res.best_estimator_.predict(X_train_encod_scaledNonRes) )
score_er['r2 log + test']= r2_score( np.log1p(y_testNonRes), res.best_estimator_.predict(X_test_encod_scaledNonRes)  )

score_er['r2 train']= r2_score( y_trainNonRes, np.expm1(res.best_estimator_.predict(X_train_encod_scaledNonRes)) )
score_er['r2 test']= r2_score( y_testNonRes, np.expm1(res.best_estimator_.predict(X_test_encod_scaledNonRes))) 

pd.DataFrame(score_er,index=['RMSE'])
# Out:
#       rmse log + train  rmse log + test    rmse train     rmse test  \
# RMSE          0.354742         0.646258  10247.318489  19648.326935
#
#       r2 log + train  r2 log + test  r2 train  r2 test
# RMSE        0.811773       0.655283  0.833131  0.60698

# %%
#LightGbm
from sklearn.metrics import mean_squared_error,r2_score

score_er = dict()
score_er['rmse log + train']= mean_squared_error( np.log1p(y_trainNonRes),resLGbm.best_estimator_.predict(X_train_encod_scaledNonRes), squared=True )
score_er['rmse log + test']= mean_squared_error( np.log1p(y_testNonRes),resLGbm.best_estimator_.predict(X_test_encod_scaledNonRes), squared=True )

score_er['rmse train']= mean_squared_error( y_trainNonRes,np.expm1(resLGbm.best_estimator_.predict(X_train_encod_scaledNonRes)), squared=True )
score_er['rmse test']= mean_squared_error(  y_testNonRes,np.expm1(resLGbm.best_estimator_.predict(X_test_encod_scaledNonRes)),squared=True) 

score_er['r2 log + train']= r2_score( np.log1p(y_trainNonRes), resLGbm.best_estimator_.predict(X_train_encod_scaledNonRes) )
score_er['r2 log + test']= r2_score( np.log1p(y_testNonRes), resLGbm.best_estimator_.predict(X_test_encod_scaledNonRes) )

score_er['r2 train']= r2_score(y_trainNonRes, np.expm1(resLGbm.best_estimator_.predict(X_train_encod_scaledNonRes)) )
score_er['r2 test']= r2_score(y_testNonRes, np.expm1(resLGbm.best_estimator_.predict(X_test_encod_scaledNonRes)) ) 

pd.DataFrame(score_er,index=['RMSE'])
# Out:
#       rmse log + train  rmse log + test    rmse train     rmse test  \
# RMSE          0.247356         0.691566  13849.952403  25745.522844
#
#       r2 log + train  r2 log + test  r2 train   r2 test
# RMSE        0.868752       0.631115  0.774465  0.485019

# %%
resXGB = xgboost_grid.fit(X_train_encod_scaled, np.log1p(y_train))
# Print the model parameters of the best model
print(res.best_params_)
# Out:
# {'alpha': 0.1, 'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100, 'objective': 'reg:squarederror'}

# %%
# %%time
# https://xgboost.readthedocs.io/en/latest/parameter.html
import xgboost as xgb
from sklearn.metrics import mean_squared_error

params_grid_xgboost =  {'max_depth': [2,3, 4],
                        'n_estimators': [50, 100],
                        'objective' :['reg:squarederror','reg:pseudohubererror','reg:gamma'], 
                        'learning_rate' : [0.1,0.2,0.5,0.9],
                        'alpha' : [0,0.1,0.2,1,5,10]
                       }
###### xgboost inner loop
xgboost_grid = GridSearchCV(estimator = xgb.XGBRegressor(), 
                            param_grid = params_grid_xgboost,
                            #early_stopping_rounds=10,
                            n_jobs=7,scoring='neg_root_mean_squared_error',
                            cv=inner_cv)
# xgboost outer loop
#do_cross_validation_upgrade(xgboost_grid,X_train_encod_scaled, y_train, print_model=True)
print('_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_')
print('Resultat log1p(y):')
do_cross_validation_upgrade(xgboost_grid,X_train_encod_scaled, np.log1p(y_train), print_model=True)
# Out:
# _-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-__-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_
# Resultat log1p(y):
# GridSearchCV(cv=KFold(n_splits=3, random_state=0, shuffle=True),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=...
#                                     random_state=None, reg_alpha=None,
#                                     reg_lambda=None, scale_pos_weight=None,
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              n_jobs=7,
#              param_grid={'alpha': [0, 0.1, 0.2, 1, 5, 10],
#                          'learning_rate': [0.1, 0.2, 0.5, 0.9],
#                          'max_depth': [2, 3, 4], 'n_estimators': [50, 100],
#                          'objective': ['reg:squarederror',
#                                        'reg:pseudohubererror', 'reg:gamma']},
#              scoring='neg_root_mean_squared_error'):
# 	Cross-validated rmse: (-0.58 + -0.56 + -0.61) / 3 = -0.5831
#
#
#
# GridSearchCV(cv=KFold(n_splits=3, random_state=0, shuffle=True),
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     enable_categorical=False, gamma=None,
#                                     gpu_id=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, max_delta_step=None,
#                                     max_depth=None, min_child_weight=...
#                                     random_state=None, reg_alpha=None,
#                                     reg_lambda=None, scale_pos_weight=None,
#                                     subsample=None, tree_method=None,
#                                     validate_parameters=None, verbosity=None),
#              n_jobs=7,
#              param_grid={'alpha': [0, 0.1, 0.2, 1, 5, 10],
#                          'learning_rate': [0.1, 0.2, 0.5, 0.9],
#                          'max_depth': [2, 3, 4], 'n_estimators': [50, 100],
#                          'objective': ['reg:squarederror',
#                                        'reg:pseudohubererror', 'reg:gamma']},
#              scoring='neg_root_mean_squared_error'):
# 	Cross-validated r2: (0.69 + 0.71 + 0.69) / 3 = 0.6987
#
# CPU times: total: 24 s
# Wall time: 5min 41s
